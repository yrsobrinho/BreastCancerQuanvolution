# %%
# !pip install pydicom
# !pip install medmnist
# !pip install pennylane
# Out:
# Requirement already satisfied: pydicom in c:\users\enzog\miniconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: medmnist in c:\users\enzog\miniconda3\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in c:\users\enzog\miniconda3\lib\site-packages (from medmnist) (1.26.4)
# Requirement already satisfied: pandas in c:\users\enzog\miniconda3\lib\site-packages (from medmnist) (2.2.1)
# Requirement already satisfied: scikit-learn in c:\users\enzog\miniconda3\lib\site-packages (from medmnist) (1.5.1)
# Requirement already satisfied: scikit-image in c:\users\enzog\miniconda3\lib\site-packages (from medmnist) (0.24.0)
# Requirement already satisfied: tqdm in c:\users\enzog\miniconda3\lib\site-packages (from medmnist) (4.66.5)
# Requirement already satisfied: Pillow in c:\users\enzog\miniconda3\lib\site-packages (from medmnist) (10.2.0)
# Requirement already satisfied: fire in c:\users\enzog\miniconda3\lib\site-packages (from medmnist) (0.7.0)
# Requirement already satisfied: torch in c:\users\enzog\miniconda3\lib\site-packages (from medmnist) (2.2.1+cu118)
# Requirement already satisfied: torchvision in c:\users\enzog\miniconda3\lib\site-packages (from medmnist) (0.17.1)
# Requirement already satisfied: termcolor in c:\users\enzog\miniconda3\lib\site-packages (from fire->medmnist) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\enzog\miniconda3\lib\site-packages (from pandas->medmnist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\enzog\miniconda3\lib\site-packages (from pandas->medmnist) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\enzog\miniconda3\lib\site-packages (from pandas->medmnist) (2024.1)
# Requirement already satisfied: scipy>=1.9 in c:\users\enzog\miniconda3\lib\site-packages (from scikit-image->medmnist) (1.12.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\enzog\miniconda3\lib\site-packages (from scikit-image->medmnist) (3.2.1)
# Requirement already satisfied: imageio>=2.33 in c:\users\enzog\miniconda3\lib\site-packages (from scikit-image->medmnist) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\enzog\miniconda3\lib\site-packages (from scikit-image->medmnist) (2024.8.24)
# Requirement already satisfied: packaging>=21 in c:\users\enzog\miniconda3\lib\site-packages (from scikit-image->medmnist) (23.1)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\enzog\miniconda3\lib\site-packages (from scikit-image->medmnist) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\enzog\miniconda3\lib\site-packages (from scikit-learn->medmnist) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\enzog\miniconda3\lib\site-packages (from scikit-learn->medmnist) (3.5.0)
# Requirement already satisfied: filelock in c:\users\enzog\miniconda3\lib\site-packages (from torch->medmnist) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\enzog\miniconda3\lib\site-packages (from torch->medmnist) (4.9.0)
# Requirement already satisfied: sympy in c:\users\enzog\miniconda3\lib\site-packages (from torch->medmnist) (1.12)
# Requirement already satisfied: jinja2 in c:\users\enzog\miniconda3\lib\site-packages (from torch->medmnist) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\enzog\miniconda3\lib\site-packages (from torch->medmnist) (2024.2.0)
# Requirement already satisfied: colorama in c:\users\enzog\miniconda3\lib\site-packages (from tqdm->medmnist) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\enzog\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->medmnist) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\enzog\miniconda3\lib\site-packages (from jinja2->torch->medmnist) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\enzog\miniconda3\lib\site-packages (from sympy->torch->medmnist) (1.3.0)
# Requirement already satisfied: pennylane in c:\users\enzog\miniconda3\lib\site-packages (0.40.0)
# Requirement already satisfied: numpy<2.1 in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (1.26.4)
# Requirement already satisfied: scipy in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (1.12.0)
# Requirement already satisfied: networkx in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (3.2.1)
# Requirement already satisfied: rustworkx>=0.14.0 in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (0.16.0)
# Requirement already satisfied: autograd in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (1.7.0)
# Requirement already satisfied: tomlkit in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (0.13.2)
# Requirement already satisfied: appdirs in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (1.4.4)
# Requirement already satisfied: autoray>=0.6.11 in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (0.7.0)
# Requirement already satisfied: cachetools in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (5.3.2)
# Requirement already satisfied: pennylane-lightning>=0.40 in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (0.40.0)
# Requirement already satisfied: requests in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (2.32.3)
# Requirement already satisfied: typing-extensions in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (4.9.0)
# Requirement already satisfied: packaging in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (23.1)
# Requirement already satisfied: diastatic-malt in c:\users\enzog\miniconda3\lib\site-packages (from pennylane) (2.15.2)
# Requirement already satisfied: scipy-openblas32>=0.3.26 in c:\users\enzog\miniconda3\lib\site-packages (from pennylane-lightning>=0.40->pennylane) (0.3.29.0.0)
# Requirement already satisfied: astunparse in c:\users\enzog\miniconda3\lib\site-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in c:\users\enzog\miniconda3\lib\site-packages (from diastatic-malt->pennylane) (0.5.4)
# Requirement already satisfied: termcolor in c:\users\enzog\miniconda3\lib\site-packages (from diastatic-malt->pennylane) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\enzog\miniconda3\lib\site-packages (from requests->pennylane) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\enzog\miniconda3\lib\site-packages (from requests->pennylane) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\enzog\miniconda3\lib\site-packages (from requests->pennylane) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\enzog\miniconda3\lib\site-packages (from requests->pennylane) (2024.2.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\enzog\miniconda3\lib\site-packages (from astunparse->diastatic-malt->pennylane) (0.41.2)
# Requirement already satisfied: six<2.0,>=1.6.1 in c:\users\enzog\miniconda3\lib\site-packages (from astunparse->diastatic-malt->pennylane) (1.16.0)

# %%
import os

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torch.utils.data as data
import torchvision.transforms as transforms
from torchvision.models import alexnet, AlexNet_Weights
import torch.nn.functional as F
from pydicom import Dataset

from tqdm import tqdm

from medmnist import BreastMNIST
from medmnist import INFO

import pennylane as qml

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print(f"Using: {torch.cuda.get_device_name(0)}")
    print(f"CUDA: {torch.version.cuda}")
else:
    print("CUDA is not available. Using CPU.")
# Out:
# Using: NVIDIA GeForce RTX 3050 6GB Laptop GPU
# CUDA: 11.8

# %%
info = INFO['breastmnist']
data_flag = 'breastmnist'
DataClass = BreastMNIST

task = info['task']  
n_channels = info['n_channels']
n_classes = len(info['label'])

print(f"Number of classes:", n_classes)
print(f"Number of channels: {n_channels}")

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),  
    transforms.RandomRotation(degrees=15),  
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5]),
    lambda x: x.unsqueeze(0)
])

eval_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5]),
    lambda x: x.unsqueeze(0)
])
# Out:
# Number of classes: 2
# Number of channels: 1

# %%
# data_train28 = DataClass(split='train', transform=train_transform, download=True)
# data_test28 = DataClass(split='test', transform=eval_transform, download=True)
# data_eval28 = DataClass(split='val', transform=eval_transform, download=True)

data_train64 = DataClass(split='train', transform=train_transform, download=True, size=64)
data_test64 = DataClass(split='test', transform=eval_transform, download=True, size=64)
data_eval64 = DataClass(split='val', transform=eval_transform, download=True, size=64)
# Out:
# Using downloaded and verified file: C:\Users\enzog\.medmnist\breastmnist_64.npz
# Using downloaded and verified file: C:\Users\enzog\.medmnist\breastmnist_64.npz
# Using downloaded and verified file: C:\Users\enzog\.medmnist\breastmnist_64.npz

# %%
batch_size = 32 

# dataloader_train = data.DataLoader(dataset=data_train28, batch_size=batch_size, shuffle=True)
# dataloader_test = data.DataLoader(dataset=data_test28, batch_size=batch_size, shuffle=False)
# dataloader_eval = data.DataLoader(dataset=data_eval28, batch_size=batch_size, shuffle=False)

# print(f"\nNumber of images in training dataset: {len(data_train28)}")
# print(f"Number of images in test dataset: {len(data_test28)}")
# print(f"Number of images in validation dataset: {len(data_eval28)}")

dataloader_train = data.DataLoader(dataset=data_train64, batch_size=batch_size, shuffle=True)
dataloader_test = data.DataLoader(dataset=data_test64, batch_size=batch_size, shuffle=False)
dataloader_eval = data.DataLoader(dataset=data_eval64, batch_size=batch_size, shuffle=False)

print(f"\nNumber of images in training dataset: {len(data_train64)}")
print(f"Number of images in test dataset: {len(data_test64)}")
print(f"Number of images in validation dataset: {len(data_eval64)}")
# Out:
# Number of images in training dataset: 546
# Number of images in test dataset: 156
# Number of images in validation dataset: 78

# %%
model = alexnet(weights=AlexNet_Weights.DEFAULT)

# Freeze model parameters
for param in model.parameters():
    param.requires_grad = True

print(model)
# Change the final layer of VGG16 Model for Transfer Learning
fc_inputs = model.classifier[1].in_features
model.classifier = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Linear(128, 1),
    #nn.ReLU(),
    #nn.Dropout(0.4),
    #nn.Linear(64, 1),
    nn.Sigmoid()
)

model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.BCELoss().to(device)
epochs = 20
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
from sklearn.metrics import precision_recall_fscore_support

train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
val_precisions = []
val_recalls = []
val_f1_scores = []
val_aucs = []

for epoch in range(epochs):
        print("Epoch: {}/{}".format(epoch+1, epochs))
        # Set to training mode
        model.train()
        # Loss and Accuracy within the epoch
        total_loss = 0.0
        total_acc = 0.0
        print("\n[Training]")
        for i, (inputs, labels) in enumerate(dataloader_train):
            inputs = inputs.squeeze(1).to(device)
            inputs = inputs.repeat(1, 3, 1, 1) # For models that need 3 channels
            labels = labels.to(device).type(torch.float)     
            # Clean existing gradients
            optimizer.zero_grad()
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            # print(f"Labels shape: {labels.shape}")
            # print(f"Outputs shape: {outputs.shape}")
            # Compute loss
            loss = criterion(outputs, labels)
            # Backpropagate the gradients
            loss.backward()
            # Update the parameters
            optimizer.step()
            # Compute the total loss for the batch and add it to train_loss
            total_loss += loss.item()
            # Compute the accuracy
            predictions = outputs.round()
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            # Compute total accuracy in the whole batch and add to train_acc
            total_acc += acc.item()
            print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

        epoch_train_loss = total_loss / len(dataloader_train)
        train_losses.append(epoch_train_loss)
        print(f"Epoch Training Loss: {epoch_train_loss:.4f}")

        epoch_train_acc = total_acc / len(dataloader_train)
        train_accuracies.append(epoch_train_acc)
        print(f"Epoch Training Accuracy: {epoch_train_acc:.4f}")

        model.eval()
        val_loss = 0.0
        val_acc = 0.0
        val_labels, val_predictions = [], []
        print("\n[Validation]")
        with torch.no_grad():
            for i, (inputs, labels) in enumerate(dataloader_eval):
                inputs = inputs.squeeze(1).to(device)
                inputs = inputs.repeat(1, 3, 1, 1) # For models that need 3 channels
                labels = labels.to(device).type(torch.float)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                val_labels.extend(labels.round().cpu().numpy())
                val_predictions.extend(outputs.round().cpu().numpy())
                # Compute the accuracy
                predictions = outputs.round()
                correct_counts = predictions.eq(labels.data.view_as(predictions))
                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))
                # Compute total accuracy in the whole batch and add to train_acc
                val_acc += acc.item()
                print("Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

        epoch_val_loss = val_loss / len(dataloader_eval)
        val_losses.append(epoch_val_loss)
        print(f"Epoch Validation Loss: {epoch_val_loss:.4f}")

        epoch_val_acc = val_acc / len(dataloader_eval)
        val_accuracies.append(epoch_val_acc)
        print(f"Epoch Validation Accuracy: {epoch_val_acc:.4f}")

        precision, recall, fscore, _ = precision_recall_fscore_support(val_labels, val_predictions, average="weighted", zero_division=np.nan)
        print(f"Accuracy: {epoch_val_acc} | Precision: {precision} | Recall: {recall} | F1: {fscore} | Avg Loss: {epoch_val_loss}")
# Out:
# Epoch: 1/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.7082, Accuracy: 0.4062
# Batch number: 001, Training: Loss: 0.5276, Accuracy: 0.7812
# Batch number: 002, Training: Loss: 0.5519, Accuracy: 0.7812
# Batch number: 003, Training: Loss: 0.5889, Accuracy: 0.7500
# Batch number: 004, Training: Loss: 0.4762, Accuracy: 0.7500
# Batch number: 005, Training: Loss: 0.5910, Accuracy: 0.6875
# Batch number: 006, Training: Loss: 0.5454, Accuracy: 0.7188
# Batch number: 007, Training: Loss: 0.4863, Accuracy: 0.8125
# Batch number: 008, Training: Loss: 0.5256, Accuracy: 0.7500
# Batch number: 009, Training: Loss: 0.5284, Accuracy: 0.7812
# Batch number: 010, Training: Loss: 0.3799, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.5129, Accuracy: 0.7812
# Batch number: 012, Training: Loss: 0.5504, Accuracy: 0.6250
# Batch number: 013, Training: Loss: 0.6943, Accuracy: 0.6250
# Batch number: 014, Training: Loss: 0.5486, Accuracy: 0.7812
# Batch number: 015, Training: Loss: 0.6221, Accuracy: 0.6250
# Batch number: 016, Training: Loss: 0.5111, Accuracy: 0.7812
# Batch number: 017, Training: Loss: 0.2607, Accuracy: 1.0000
# Epoch Training Loss: 0.5339
# Epoch Training Accuracy: 0.7413
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4614, Accuracy: 0.7188
# Batch number: 001, Validation: Loss: 0.4484, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.3985, Accuracy: 0.8571
# Epoch Validation Loss: 0.4361
# Epoch Validation Accuracy: 0.8170
# Accuracy: 0.8169642885526022 | Precision: 0.806447963800905 | Recall: 0.8076923076923077 | F1: 0.7820347394540943 | Avg Loss: 0.43610567847887677
# Epoch: 2/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.3817, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.5387, Accuracy: 0.7500
# Batch number: 002, Training: Loss: 0.3886, Accuracy: 0.8750
# Batch number: 003, Training: Loss: 0.4938, Accuracy: 0.7812
# Batch number: 004, Training: Loss: 0.4561, Accuracy: 0.7812
# Batch number: 005, Training: Loss: 0.4285, Accuracy: 0.8125
# Batch number: 006, Training: Loss: 0.4541, Accuracy: 0.7812
# Batch number: 007, Training: Loss: 0.4169, Accuracy: 0.8125
# Batch number: 008, Training: Loss: 0.3857, Accuracy: 0.8438
# Batch number: 009, Training: Loss: 0.5078, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.4523, Accuracy: 0.7812
# Batch number: 011, Training: Loss: 0.3442, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.3546, Accuracy: 0.8125
# Batch number: 013, Training: Loss: 0.5565, Accuracy: 0.7500
# Batch number: 014, Training: Loss: 0.4525, Accuracy: 0.7812
# Batch number: 015, Training: Loss: 0.4162, Accuracy: 0.7812
# Batch number: 016, Training: Loss: 0.3675, Accuracy: 0.8438
# Batch number: 017, Training: Loss: 0.2567, Accuracy: 1.0000
# Epoch Training Loss: 0.4251
# Epoch Training Accuracy: 0.8281
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.6019, Accuracy: 0.7500
# Batch number: 001, Validation: Loss: 0.4407, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.3571, Accuracy: 0.8571
# Epoch Validation Loss: 0.4666
# Epoch Validation Accuracy: 0.8274
# Accuracy: 0.8273809552192688 | Precision: 0.8324043106651803 | Recall: 0.8205128205128205 | F1: 0.7931623931623931 | Avg Loss: 0.4665627678235372
# Epoch: 3/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.4574, Accuracy: 0.7500
# Batch number: 001, Training: Loss: 0.2707, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.2707, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.3314, Accuracy: 0.8125
# Batch number: 004, Training: Loss: 0.2407, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.4405, Accuracy: 0.8125
# Batch number: 006, Training: Loss: 0.6276, Accuracy: 0.7812
# Batch number: 007, Training: Loss: 0.4419, Accuracy: 0.8438
# Batch number: 008, Training: Loss: 0.3485, Accuracy: 0.9062
# Batch number: 009, Training: Loss: 0.5313, Accuracy: 0.8125
# Batch number: 010, Training: Loss: 0.3981, Accuracy: 0.8438
# Batch number: 011, Training: Loss: 0.4066, Accuracy: 0.8125
# Batch number: 012, Training: Loss: 0.4324, Accuracy: 0.7500
# Batch number: 013, Training: Loss: 0.5562, Accuracy: 0.6250
# Batch number: 014, Training: Loss: 0.3167, Accuracy: 0.8438
# Batch number: 015, Training: Loss: 0.4758, Accuracy: 0.7812
# Batch number: 016, Training: Loss: 0.3203, Accuracy: 0.9375
# Batch number: 017, Training: Loss: 0.1384, Accuracy: 1.0000
# Epoch Training Loss: 0.3892
# Epoch Training Accuracy: 0.8368
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4668, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.3064, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.2516, Accuracy: 0.9286
# Epoch Validation Loss: 0.3416
# Epoch Validation Accuracy: 0.8929
# Accuracy: 0.8928571343421936 | Precision: 0.8894230769230769 | Recall: 0.8846153846153846 | F1: 0.8764144945963127 | Avg Loss: 0.3416094382603963
# Epoch: 4/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.3658, Accuracy: 0.8438
# Batch number: 001, Training: Loss: 0.2304, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.2655, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.3471, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.1389, Accuracy: 0.9688
# Batch number: 005, Training: Loss: 0.4926, Accuracy: 0.7812
# Batch number: 006, Training: Loss: 0.3318, Accuracy: 0.9062
# Batch number: 007, Training: Loss: 0.2704, Accuracy: 0.9375
# Batch number: 008, Training: Loss: 0.6280, Accuracy: 0.8125
# Batch number: 009, Training: Loss: 0.8013, Accuracy: 0.7188
# Batch number: 010, Training: Loss: 0.5025, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.4747, Accuracy: 0.8125
# Batch number: 012, Training: Loss: 0.4875, Accuracy: 0.8125
# Batch number: 013, Training: Loss: 0.4368, Accuracy: 0.7812
# Batch number: 014, Training: Loss: 0.4460, Accuracy: 0.8125
# Batch number: 015, Training: Loss: 0.3714, Accuracy: 0.8438
# Batch number: 016, Training: Loss: 0.4129, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 0.1984, Accuracy: 1.0000
# Epoch Training Loss: 0.4001
# Epoch Training Accuracy: 0.8576
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4255, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.3369, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.3486, Accuracy: 0.9286
# Epoch Validation Loss: 0.3703
# Epoch Validation Accuracy: 0.8824
# Accuracy: 0.882440467675527 | Precision: 0.8781065088757396 | Recall: 0.8717948717948718 | F1: 0.8609153623618427 | Avg Loss: 0.3703039884567261
# Epoch: 5/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.3345, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.4393, Accuracy: 0.7812
# Batch number: 002, Training: Loss: 0.3754, Accuracy: 0.8125
# Batch number: 003, Training: Loss: 0.4301, Accuracy: 0.7500
# Batch number: 004, Training: Loss: 0.4493, Accuracy: 0.7500
# Batch number: 005, Training: Loss: 0.4769, Accuracy: 0.7812
# Batch number: 006, Training: Loss: 0.3828, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.4608, Accuracy: 0.7500
# Batch number: 008, Training: Loss: 0.3547, Accuracy: 0.8438
# Batch number: 009, Training: Loss: 0.4947, Accuracy: 0.8125
# Batch number: 010, Training: Loss: 0.3455, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.3701, Accuracy: 0.8125
# Batch number: 012, Training: Loss: 0.3922, Accuracy: 0.7812
# Batch number: 013, Training: Loss: 0.3823, Accuracy: 0.8125
# Batch number: 014, Training: Loss: 0.4058, Accuracy: 0.8125
# Batch number: 015, Training: Loss: 0.2385, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.4209, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 0.7900, Accuracy: 0.5000
# Epoch Training Loss: 0.4191
# Epoch Training Accuracy: 0.8021
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4661, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.3349, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.2840, Accuracy: 0.9286
# Epoch Validation Loss: 0.3617
# Epoch Validation Accuracy: 0.8824
# Accuracy: 0.882440467675527 | Precision: 0.8781065088757396 | Recall: 0.8717948717948718 | F1: 0.8609153623618427 | Avg Loss: 0.36167927583058673
# Epoch: 6/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.4612, Accuracy: 0.7500
# Batch number: 001, Training: Loss: 0.3717, Accuracy: 0.8750
# Batch number: 002, Training: Loss: 0.5061, Accuracy: 0.6875
# Batch number: 003, Training: Loss: 0.2967, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.2278, Accuracy: 0.9688
# Batch number: 005, Training: Loss: 0.3014, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.3165, Accuracy: 0.9062
# Batch number: 007, Training: Loss: 0.3269, Accuracy: 0.8750
# Batch number: 008, Training: Loss: 0.3106, Accuracy: 0.8438
# Batch number: 009, Training: Loss: 0.3682, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.2306, Accuracy: 0.9688
# Batch number: 011, Training: Loss: 0.2914, Accuracy: 0.8750
# Batch number: 012, Training: Loss: 0.2913, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.3541, Accuracy: 0.9062
# Batch number: 014, Training: Loss: 0.3938, Accuracy: 0.7812
# Batch number: 015, Training: Loss: 0.2019, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.2435, Accuracy: 0.9375
# Batch number: 017, Training: Loss: 0.8015, Accuracy: 0.5000
# Epoch Training Loss: 0.3497
# Epoch Training Accuracy: 0.8507
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4929, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.2737, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.1894, Accuracy: 0.8571
# Epoch Validation Loss: 0.3187
# Epoch Validation Accuracy: 0.8690
# Accuracy: 0.8690476218859354 | Precision: 0.8686299235961724 | Recall: 0.8717948717948718 | F1: 0.8672202017429493 | Avg Loss: 0.31866350769996643
# Epoch: 7/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.1891, Accuracy: 0.9375
# Batch number: 001, Training: Loss: 0.4049, Accuracy: 0.8750
# Batch number: 002, Training: Loss: 0.1714, Accuracy: 0.9688
# Batch number: 003, Training: Loss: 0.2981, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.3254, Accuracy: 0.8438
# Batch number: 005, Training: Loss: 0.5082, Accuracy: 0.7812
# Batch number: 006, Training: Loss: 0.1877, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.2419, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.2484, Accuracy: 0.9062
# Batch number: 009, Training: Loss: 0.2556, Accuracy: 0.9062
# Batch number: 010, Training: Loss: 0.3388, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.4031, Accuracy: 0.8125
# Batch number: 012, Training: Loss: 0.2535, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.3556, Accuracy: 0.8438
# Batch number: 014, Training: Loss: 0.3184, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.3815, Accuracy: 0.8125
# Batch number: 016, Training: Loss: 0.3437, Accuracy: 0.8750
# Batch number: 017, Training: Loss: 0.4204, Accuracy: 0.5000
# Epoch Training Loss: 0.3137
# Epoch Training Accuracy: 0.8628
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4251, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.2648, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.1962, Accuracy: 0.8571
# Epoch Validation Loss: 0.2954
# Epoch Validation Accuracy: 0.8586
# Accuracy: 0.8586309552192688 | Precision: 0.8570954907161803 | Recall: 0.8589743589743589 | F1: 0.8578676890447833 | Avg Loss: 0.29536602397759754
# Epoch: 8/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.2372, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.3203, Accuracy: 0.8438
# Batch number: 002, Training: Loss: 0.2331, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.3103, Accuracy: 0.7812
# Batch number: 004, Training: Loss: 0.4526, Accuracy: 0.8438
# Batch number: 005, Training: Loss: 0.2550, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.3619, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.2863, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.5078, Accuracy: 0.7500
# Batch number: 009, Training: Loss: 0.5114, Accuracy: 0.7812
# Batch number: 010, Training: Loss: 0.3117, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.2482, Accuracy: 0.8750
# Batch number: 012, Training: Loss: 0.2803, Accuracy: 0.8438
# Batch number: 013, Training: Loss: 0.2587, Accuracy: 0.8750
# Batch number: 014, Training: Loss: 0.2292, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.2981, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.4231, Accuracy: 0.8438
# Batch number: 017, Training: Loss: 0.1487, Accuracy: 1.0000
# Epoch Training Loss: 0.3152
# Epoch Training Accuracy: 0.8681
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3711, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.3010, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.2676, Accuracy: 0.8571
# Epoch Validation Loss: 0.3132
# Epoch Validation Accuracy: 0.8690
# Accuracy: 0.8690476218859354 | Precision: 0.8781065088757396 | Recall: 0.8717948717948718 | F1: 0.8609153623618427 | Avg Loss: 0.3132293224334717
# Epoch: 9/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.2855, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.1253, Accuracy: 0.9688
# Batch number: 002, Training: Loss: 0.3720, Accuracy: 0.8750
# Batch number: 003, Training: Loss: 0.2336, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.2599, Accuracy: 0.8750
# Batch number: 005, Training: Loss: 0.2616, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.2399, Accuracy: 0.9062
# Batch number: 007, Training: Loss: 0.2673, Accuracy: 0.8438
# Batch number: 008, Training: Loss: 0.3608, Accuracy: 0.8750
# Batch number: 009, Training: Loss: 0.3563, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.2538, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.1406, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.3289, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.2084, Accuracy: 0.9062
# Batch number: 014, Training: Loss: 0.3943, Accuracy: 0.8750
# Batch number: 015, Training: Loss: 0.5283, Accuracy: 0.8438
# Batch number: 016, Training: Loss: 0.3571, Accuracy: 0.8438
# Batch number: 017, Training: Loss: 0.0195, Accuracy: 1.0000
# Epoch Training Loss: 0.2774
# Epoch Training Accuracy: 0.8941
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4649, Accuracy: 0.8750
# Batch number: 001, Validation: Loss: 0.2599, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.1253, Accuracy: 1.0000
# Epoch Validation Loss: 0.2833
# Epoch Validation Accuracy: 0.9271
# Accuracy: 0.9270833333333334 | Precision: 0.9124534739454094 | Recall: 0.9102564102564102 | F1: 0.9060780237250825 | Avg Loss: 0.28334610164165497
# Epoch: 10/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.1294, Accuracy: 0.9688
# Batch number: 001, Training: Loss: 0.3477, Accuracy: 0.8438
# Batch number: 002, Training: Loss: 0.1972, Accuracy: 0.9688
# Batch number: 003, Training: Loss: 0.3465, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.1690, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.3260, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.2115, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.2097, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.4723, Accuracy: 0.7500
# Batch number: 009, Training: Loss: 0.2243, Accuracy: 0.9062
# Batch number: 010, Training: Loss: 0.2071, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.3465, Accuracy: 0.8438
# Batch number: 012, Training: Loss: 0.2441, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.2655, Accuracy: 0.9062
# Batch number: 014, Training: Loss: 0.1514, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.3760, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.3585, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 0.1115, Accuracy: 1.0000
# Epoch Training Loss: 0.2608
# Epoch Training Accuracy: 0.9028
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3700, Accuracy: 0.8750
# Batch number: 001, Validation: Loss: 0.2206, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.1657, Accuracy: 1.0000
# Epoch Validation Loss: 0.2521
# Epoch Validation Accuracy: 0.9271
# Accuracy: 0.9270833333333334 | Precision: 0.9124534739454094 | Recall: 0.9102564102564102 | F1: 0.9060780237250825 | Avg Loss: 0.25210346281528473
# Epoch: 11/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.4017, Accuracy: 0.8125
# Batch number: 001, Training: Loss: 0.4205, Accuracy: 0.8438
# Batch number: 002, Training: Loss: 0.3610, Accuracy: 0.7812
# Batch number: 003, Training: Loss: 0.1155, Accuracy: 1.0000
# Batch number: 004, Training: Loss: 0.3679, Accuracy: 0.8438
# Batch number: 005, Training: Loss: 0.1339, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.1604, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.2262, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.1805, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.2059, Accuracy: 0.9375
# Batch number: 010, Training: Loss: 0.1610, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.2406, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.3015, Accuracy: 0.8750
# Batch number: 013, Training: Loss: 0.2240, Accuracy: 0.9062
# Batch number: 014, Training: Loss: 0.3250, Accuracy: 0.8438
# Batch number: 015, Training: Loss: 0.0933, Accuracy: 0.9688
# Batch number: 016, Training: Loss: 0.1632, Accuracy: 0.9375
# Batch number: 017, Training: Loss: 0.0186, Accuracy: 1.0000
# Epoch Training Loss: 0.2278
# Epoch Training Accuracy: 0.9080
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.6232, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.3939, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.2810, Accuracy: 0.8571
# Epoch Validation Loss: 0.4327
# Epoch Validation Accuracy: 0.8690
# Accuracy: 0.8690476218859354 | Precision: 0.8781065088757396 | Recall: 0.8717948717948718 | F1: 0.8609153623618427 | Avg Loss: 0.4326997498671214
# Epoch: 12/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.8062, Accuracy: 0.7500
# Batch number: 001, Training: Loss: 0.2917, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.1733, Accuracy: 0.9375
# Batch number: 003, Training: Loss: 0.2209, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.3741, Accuracy: 0.8125
# Batch number: 005, Training: Loss: 0.2269, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.2885, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.1851, Accuracy: 0.9375
# Batch number: 008, Training: Loss: 0.1917, Accuracy: 0.9375
# Batch number: 009, Training: Loss: 0.3452, Accuracy: 0.9375
# Batch number: 010, Training: Loss: 0.2137, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.0909, Accuracy: 0.9688
# Batch number: 012, Training: Loss: 0.1884, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.4707, Accuracy: 0.7812
# Batch number: 014, Training: Loss: 0.2866, Accuracy: 0.8750
# Batch number: 015, Training: Loss: 0.1721, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.1830, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 0.2574, Accuracy: 1.0000
# Epoch Training Loss: 0.2759
# Epoch Training Accuracy: 0.8958
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4417, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.2687, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.1916, Accuracy: 0.9286
# Epoch Validation Loss: 0.3007
# Epoch Validation Accuracy: 0.8929
# Accuracy: 0.8928571343421936 | Precision: 0.8820512820512822 | Recall: 0.8846153846153846 | F1: 0.8816568047337279 | Avg Loss: 0.3006862501303355
# Epoch: 13/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.1210, Accuracy: 0.9688
# Batch number: 001, Training: Loss: 0.3974, Accuracy: 0.8125
# Batch number: 002, Training: Loss: 0.2596, Accuracy: 0.8750
# Batch number: 003, Training: Loss: 0.2574, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.2961, Accuracy: 0.8750
# Batch number: 005, Training: Loss: 0.2634, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.1572, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.2421, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.2694, Accuracy: 0.8750
# Batch number: 009, Training: Loss: 0.1561, Accuracy: 1.0000
# Batch number: 010, Training: Loss: 0.2503, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.1688, Accuracy: 0.9688
# Batch number: 012, Training: Loss: 0.3540, Accuracy: 0.8438
# Batch number: 013, Training: Loss: 0.2302, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.2181, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.0911, Accuracy: 0.9688
# Batch number: 016, Training: Loss: 0.1815, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 0.0066, Accuracy: 1.0000
# Epoch Training Loss: 0.2178
# Epoch Training Accuracy: 0.9149
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3302, Accuracy: 0.8750
# Batch number: 001, Validation: Loss: 0.1804, Accuracy: 0.9375
# Batch number: 002, Validation: Loss: 0.0677, Accuracy: 1.0000
# Epoch Validation Loss: 0.1928
# Epoch Validation Accuracy: 0.9375
# Accuracy: 0.9375 | Precision: 0.9242637786514354 | Recall: 0.9230769230769231 | F1: 0.9203321210457696 | Avg Loss: 0.19277178247769675
# Epoch: 14/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.0919, Accuracy: 1.0000
# Batch number: 001, Training: Loss: 0.2558, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.3382, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.1605, Accuracy: 0.9375
# Batch number: 004, Training: Loss: 0.2808, Accuracy: 0.8750
# Batch number: 005, Training: Loss: 0.1255, Accuracy: 0.9688
# Batch number: 006, Training: Loss: 0.2185, Accuracy: 0.9688
# Batch number: 007, Training: Loss: 0.3819, Accuracy: 0.8750
# Batch number: 008, Training: Loss: 0.0919, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.2866, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.3154, Accuracy: 0.8438
# Batch number: 011, Training: Loss: 0.2969, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.1661, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.3318, Accuracy: 0.8438
# Batch number: 014, Training: Loss: 0.2236, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.1784, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.2376, Accuracy: 0.8750
# Batch number: 017, Training: Loss: 0.1921, Accuracy: 1.0000
# Epoch Training Loss: 0.2319
# Epoch Training Accuracy: 0.9149
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.6926, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.4096, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.3477, Accuracy: 0.9286
# Epoch Validation Loss: 0.4833
# Epoch Validation Accuracy: 0.8720
# Accuracy: 0.8720238010088602 | Precision: 0.866841491841492 | Recall: 0.8589743589743589 | F1: 0.8449030644152595 | Avg Loss: 0.4832996428012848
# Epoch: 15/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.4919, Accuracy: 0.8438
# Batch number: 001, Training: Loss: 0.1193, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.1746, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.1330, Accuracy: 0.9375
# Batch number: 004, Training: Loss: 0.1890, Accuracy: 0.9062
# Batch number: 005, Training: Loss: 0.1851, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.1409, Accuracy: 0.9688
# Batch number: 007, Training: Loss: 0.0713, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.3490, Accuracy: 0.8438
# Batch number: 009, Training: Loss: 0.3763, Accuracy: 0.8125
# Batch number: 010, Training: Loss: 0.0762, Accuracy: 0.9688
# Batch number: 011, Training: Loss: 0.2801, Accuracy: 0.8750
# Batch number: 012, Training: Loss: 0.0516, Accuracy: 1.0000
# Batch number: 013, Training: Loss: 0.1682, Accuracy: 0.9062
# Batch number: 014, Training: Loss: 0.3233, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.2760, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.2486, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 0.0285, Accuracy: 1.0000
# Epoch Training Loss: 0.2046
# Epoch Training Accuracy: 0.9167
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.2504, Accuracy: 0.8750
# Batch number: 001, Validation: Loss: 0.2083, Accuracy: 0.9375
# Batch number: 002, Validation: Loss: 0.0883, Accuracy: 1.0000
# Epoch Validation Loss: 0.1823
# Epoch Validation Accuracy: 0.9375
# Accuracy: 0.9375 | Precision: 0.9221162423660194 | Recall: 0.9230769230769231 | F1: 0.9218169761273208 | Avg Loss: 0.18232168753941855
# Epoch: 16/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.2306, Accuracy: 0.8750
# Batch number: 001, Training: Loss: 0.1603, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.1400, Accuracy: 1.0000
# Batch number: 003, Training: Loss: 0.1052, Accuracy: 0.9688
# Batch number: 004, Training: Loss: 0.2982, Accuracy: 0.8438
# Batch number: 005, Training: Loss: 0.2177, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.0760, Accuracy: 1.0000
# Batch number: 007, Training: Loss: 0.2432, Accuracy: 0.8750
# Batch number: 008, Training: Loss: 0.1119, Accuracy: 0.9375
# Batch number: 009, Training: Loss: 0.2183, Accuracy: 0.9062
# Batch number: 010, Training: Loss: 0.1913, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.2575, Accuracy: 0.8750
# Batch number: 012, Training: Loss: 0.2624, Accuracy: 0.8750
# Batch number: 013, Training: Loss: 0.2228, Accuracy: 0.9062
# Batch number: 014, Training: Loss: 0.1185, Accuracy: 0.9688
# Batch number: 015, Training: Loss: 0.0813, Accuracy: 1.0000
# Batch number: 016, Training: Loss: 0.0249, Accuracy: 1.0000
# Batch number: 017, Training: Loss: 0.0435, Accuracy: 1.0000
# Epoch Training Loss: 0.1669
# Epoch Training Accuracy: 0.9323
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5359, Accuracy: 0.8750
# Batch number: 001, Validation: Loss: 0.2439, Accuracy: 0.9375
# Batch number: 002, Validation: Loss: 0.1352, Accuracy: 0.9286
# Epoch Validation Loss: 0.3050
# Epoch Validation Accuracy: 0.9137
# Accuracy: 0.913690467675527 | Precision: 0.9200721153846154 | Recall: 0.9102564102564102 | F1: 0.9038779402415766 | Avg Loss: 0.3050166418155034
# Epoch: 17/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.2847, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.1086, Accuracy: 0.9688
# Batch number: 002, Training: Loss: 0.0664, Accuracy: 1.0000
# Batch number: 003, Training: Loss: 0.1323, Accuracy: 0.9375
# Batch number: 004, Training: Loss: 0.3039, Accuracy: 0.8438
# Batch number: 005, Training: Loss: 0.1880, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.1042, Accuracy: 0.9688
# Batch number: 007, Training: Loss: 0.1052, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.1615, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.4113, Accuracy: 0.8438
# Batch number: 010, Training: Loss: 0.1948, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.1892, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.1202, Accuracy: 0.9688
# Batch number: 013, Training: Loss: 0.2022, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.2024, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.2698, Accuracy: 0.9375
# Batch number: 016, Training: Loss: 0.2104, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 0.0062, Accuracy: 1.0000
# Epoch Training Loss: 0.1812
# Epoch Training Accuracy: 0.9358
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5655, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.3807, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.1109, Accuracy: 0.9286
# Epoch Validation Loss: 0.3524
# Epoch Validation Accuracy: 0.8929
# Accuracy: 0.8928571343421936 | Precision: 0.8894230769230769 | Recall: 0.8846153846153846 | F1: 0.8764144945963127 | Avg Loss: 0.35238053401311237
# Epoch: 18/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.2214, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.0669, Accuracy: 1.0000
# Batch number: 002, Training: Loss: 0.0742, Accuracy: 0.9688
# Batch number: 003, Training: Loss: 0.2002, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.1395, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.1474, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.1506, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.1309, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.1160, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.1098, Accuracy: 1.0000
# Batch number: 010, Training: Loss: 0.1441, Accuracy: 0.9688
# Batch number: 011, Training: Loss: 0.1390, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.1840, Accuracy: 0.8750
# Batch number: 013, Training: Loss: 0.1400, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.1746, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.1588, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.0422, Accuracy: 1.0000
# Batch number: 017, Training: Loss: 0.0356, Accuracy: 1.0000
# Epoch Training Loss: 0.1319
# Epoch Training Accuracy: 0.9479
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5131, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.2273, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.1932, Accuracy: 0.9286
# Epoch Validation Loss: 0.3112
# Epoch Validation Accuracy: 0.8929
# Accuracy: 0.8928571343421936 | Precision: 0.8894230769230769 | Recall: 0.8846153846153846 | F1: 0.8764144945963127 | Avg Loss: 0.3111839145421982
# Epoch: 19/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.1186, Accuracy: 0.9688
# Batch number: 001, Training: Loss: 0.1463, Accuracy: 0.9688
# Batch number: 002, Training: Loss: 0.1442, Accuracy: 0.9688
# Batch number: 003, Training: Loss: 0.1718, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.0913, Accuracy: 0.9688
# Batch number: 005, Training: Loss: 0.1143, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.0972, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.3098, Accuracy: 0.9375
# Batch number: 008, Training: Loss: 0.2645, Accuracy: 0.8750
# Batch number: 009, Training: Loss: 0.1054, Accuracy: 0.9688
# Batch number: 010, Training: Loss: 0.1480, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.1415, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.3619, Accuracy: 0.8438
# Batch number: 013, Training: Loss: 0.1374, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.1577, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.5554, Accuracy: 0.7500
# Batch number: 016, Training: Loss: 0.1205, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 0.0261, Accuracy: 1.0000
# Epoch Training Loss: 0.1784
# Epoch Training Accuracy: 0.9236
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4941, Accuracy: 0.8750
# Batch number: 001, Validation: Loss: 0.3106, Accuracy: 0.9375
# Batch number: 002, Validation: Loss: 0.1405, Accuracy: 1.0000
# Epoch Validation Loss: 0.3151
# Epoch Validation Accuracy: 0.9375
# Accuracy: 0.9375 | Precision: 0.9242637786514354 | Recall: 0.9230769230769231 | F1: 0.9203321210457696 | Avg Loss: 0.31507402658462524
# Epoch: 20/20
#
# [Training]
# Batch number: 000, Training: Loss: 0.1728, Accuracy: 0.8750
# Batch number: 001, Training: Loss: 0.2227, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.0601, Accuracy: 1.0000
# Batch number: 003, Training: Loss: 0.1296, Accuracy: 0.9375
# Batch number: 004, Training: Loss: 0.0732, Accuracy: 0.9688
# Batch number: 005, Training: Loss: 0.0955, Accuracy: 0.9688
# Batch number: 006, Training: Loss: 0.0999, Accuracy: 0.9688
# Batch number: 007, Training: Loss: 0.0598, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.0924, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.4335, Accuracy: 0.8438
# Batch number: 010, Training: Loss: 0.1723, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.2844, Accuracy: 0.8125
# Batch number: 012, Training: Loss: 0.0680, Accuracy: 1.0000
# Batch number: 013, Training: Loss: 0.0899, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.1751, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.1233, Accuracy: 0.9375
# Batch number: 016, Training: Loss: 0.2386, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 0.0287, Accuracy: 1.0000
# Epoch Training Loss: 0.1456
# Epoch Training Accuracy: 0.9323
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4452, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.2601, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.2520, Accuracy: 0.8571
# Epoch Validation Loss: 0.3191
# Epoch Validation Accuracy: 0.8482
# Accuracy: 0.8482142885526022 | Precision: 0.8586937590711177 | Recall: 0.8461538461538461 | F1: 0.8500456065673456 | Avg Loss: 0.31910622119903564

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), train_losses, label="Training Loss", marker='o')
plt.plot(range(1, epochs + 1), val_losses, label="Validation Loss", marker='x')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), val_accuracies, label="Validation Accuracy", marker='s', color='g')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), train_losses, label="Training Loss", marker='o')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import precision_recall_fscore_support

test_loss = 0.0
correct = 0.0
preds = []
labels_ = []

with torch.no_grad():
    model.eval()
    for i, (inputs, labels) in enumerate(dataloader_test):
        inputs = inputs.squeeze(1).to(device)
        inputs = inputs.repeat(1, 3, 1, 1) # For models that need 3 channels
        labels = labels.to(device).type(torch.float)

        outputs = model(inputs)
        preds.extend(outputs.round().cpu().numpy())
        labels_.extend(labels.round().cpu().numpy())

        loss = criterion(outputs, labels)
        test_loss += loss.item() * inputs.size(0)
        correct += (outputs.round() == labels).float().sum().item()

acc = correct / len(dataloader_test.dataset)
avg_loss = test_loss / len(dataloader_test.dataset)
precision, recall, fscore, _ = precision_recall_fscore_support(labels_, preds, average="weighted", zero_division=np.nan)
print(f"Accuracy: {acc} | Precision: {precision} | Recall: {recall} | F1: {fscore} | Avg Loss: {avg_loss}")
# Out:
# Accuracy: 0.8589743589743589 | Precision: 0.8673433048433048 | Recall: 0.8589743589743589 | F1: 0.8617694617694619 | Avg Loss: 0.43060859197225326

# %%
conf_matrix = confusion_matrix(labels_, preds)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negativo', 'Positivo'], yticklabels=['Negativo', 'Positivo'])
plt.xlabel('Predito')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()
