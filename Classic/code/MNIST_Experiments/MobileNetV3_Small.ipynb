# %%
import os

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torch.utils.data as data
import torchvision.transforms as transforms
from torchvision.models import mobilenet_v3_small, MobileNet_V3_Small_Weights
import torch.nn.functional as F
from pydicom import Dataset

from tqdm import tqdm

from medmnist import BreastMNIST
from medmnist import INFO

import pennylane as qml

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print(f"Using: {torch.cuda.get_device_name(0)}")
    print(f"CUDA: {torch.version.cuda}")
else:
    print("CUDA is not available. Using CPU.")
# Out:
# Using: NVIDIA GeForce RTX 3050 6GB Laptop GPU
# CUDA: 11.8

# %%
info = INFO['breastmnist']
data_flag = 'breastmnist'
DataClass = BreastMNIST

task = info['task']  
n_channels = info['n_channels']
n_classes = len(info['label'])

print(f"Number of classes:", n_classes)
print(f"Number of channels: {n_channels}")

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),  
    transforms.RandomRotation(degrees=15),  
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5]),
    lambda x: x.unsqueeze(0)
])

eval_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5]),
    lambda x: x.unsqueeze(0)
])
# Out:
# Number of classes: 2
# Number of channels: 1

# %%
# data_train28 = DataClass(split='train', transform=train_transform, download=True)
# data_test28 = DataClass(split='test', transform=eval_transform, download=True)
# data_eval28 = DataClass(split='val', transform=eval_transform, download=True)

data_train64 = DataClass(split='train', transform=train_transform, download=True, size=64)
data_test64 = DataClass(split='test', transform=eval_transform, download=True, size=64)
data_eval64 = DataClass(split='val', transform=eval_transform, download=True, size=64)
# Out:
# Using downloaded and verified file: C:\Users\enzog\.medmnist\breastmnist_64.npz
# Using downloaded and verified file: C:\Users\enzog\.medmnist\breastmnist_64.npz
# Using downloaded and verified file: C:\Users\enzog\.medmnist\breastmnist_64.npz

# %%
batch_size = 32 

# dataloader_train = data.DataLoader(dataset=data_train28, batch_size=batch_size, shuffle=True)
# dataloader_test = data.DataLoader(dataset=data_test28, batch_size=batch_size, shuffle=False)
# dataloader_eval = data.DataLoader(dataset=data_eval28, batch_size=batch_size, shuffle=False)

# print(f"\nNumber of images in training dataset: {len(data_train28)}")
# print(f"Number of images in test dataset: {len(data_test28)}")
# print(f"Number of images in validation dataset: {len(data_eval28)}")

dataloader_train = data.DataLoader(dataset=data_train64, batch_size=batch_size, shuffle=True)
dataloader_test = data.DataLoader(dataset=data_test64, batch_size=batch_size, shuffle=False)
dataloader_eval = data.DataLoader(dataset=data_eval64, batch_size=batch_size, shuffle=False)

print(f"\nNumber of images in training dataset: {len(data_train64)}")
print(f"Number of images in test dataset: {len(data_test64)}")
print(f"Number of images in validation dataset: {len(data_eval64)}")
# Out:
# Number of images in training dataset: 546
# Number of images in test dataset: 156
# Number of images in validation dataset: 78

# %%
# MobileNetV3Small

model = mobilenet_v3_small(weights=MobileNet_V3_Small_Weights.DEFAULT)

for param in model.parameters():
    param.requires_grad = True

fc_inputs = model.classifier[0].in_features
model.classifier = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Linear(128, 1),
    nn.Sigmoid()
)
print(model)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.BCELoss().to(device)
epochs = 50
# Out:
# MobileNetV3(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#     (1): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(8, 16, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (2): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 72, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(72, 72, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=72, bias=False)
#           (1): BatchNorm2d(72, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(72, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (3): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(88, 88, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=88, bias=False)
#           (1): BatchNorm2d(88, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(88, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (4): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(96, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (5): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (6): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#           (1): BatchNorm2d(240, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(240, 64, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(64, 240, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (7): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(40, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(120, 120, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=120, bias=False)
#           (1): BatchNorm2d(120, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(120, 32, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(32, 120, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(120, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (8): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(40, 144, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (9): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(288, 288, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=288, bias=False)
#           (1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(288, 72, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(72, 288, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (10): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (11): InvertedResidual(
#       (block): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#           (2): Hardswish()
#         )
#         (2): SqueezeExcitation(
#           (avgpool): AdaptiveAvgPool2d(output_size=1)
#           (fc1): Conv2d(576, 144, kernel_size=(1, 1), stride=(1, 1))
#           (fc2): Conv2d(144, 576, kernel_size=(1, 1), stride=(1, 1))
#           (activation): ReLU()
#           (scale_activation): Hardsigmoid()
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#         )
#       )
#     )
#     (12): Conv2dNormActivation(
#       (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (2): Hardswish()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=576, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=128, out_features=1, bias=True)
#     (6): Sigmoid()
#   )
# )

# %%
from sklearn.metrics import precision_recall_fscore_support

train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
val_precisions = []
val_recalls = []
val_f1_scores = []
val_aucs = []

for epoch in range(epochs):
        print("Epoch: {}/{}".format(epoch+1, epochs))
        # Set to training mode
        model.train()
        # Loss and Accuracy within the epoch
        total_loss = 0.0
        total_acc = 0.0
        print("\n[Training]")
        for i, (inputs, labels) in enumerate(dataloader_train):
            inputs = inputs.squeeze(1).to(device)
            inputs = inputs.repeat(1, 3, 1, 1) # For models that need 3 channels
            labels = labels.to(device).type(torch.float)     
            # Clean existing gradients
            optimizer.zero_grad()
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            # print(f"Labels shape: {labels.shape}")
            # print(f"Outputs shape: {outputs.shape}")
            # Compute loss
            loss = criterion(outputs, labels)
            # Backpropagate the gradients
            loss.backward()
            # Update the parameters
            optimizer.step()
            # Compute the total loss for the batch and add it to train_loss
            total_loss += loss.item()
            # Compute the accuracy
            predictions = outputs.round()
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            # Compute total accuracy in the whole batch and add to train_acc
            total_acc += acc.item()
            print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

        epoch_train_loss = total_loss / len(dataloader_train)
        train_losses.append(epoch_train_loss)
        print(f"Epoch Training Loss: {epoch_train_loss:.4f}")

        epoch_train_acc = total_acc / len(dataloader_train)
        train_accuracies.append(epoch_train_acc)
        print(f"Epoch Training Accuracy: {epoch_train_acc:.4f}")

        model.eval()
        val_loss = 0.0
        val_acc = 0.0
        val_labels, val_predictions = [], []
        print("\n[Validation]")
        with torch.no_grad():
            for i, (inputs, labels) in enumerate(dataloader_eval):
                inputs = inputs.squeeze(1).to(device)
                inputs = inputs.repeat(1, 3, 1, 1) # For models that need 3 channels
                labels = labels.to(device).type(torch.float)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                val_labels.extend(labels.round().cpu().numpy())
                val_predictions.extend(outputs.round().cpu().numpy())
                # Compute the accuracy
                predictions = outputs.round()
                correct_counts = predictions.eq(labels.data.view_as(predictions))
                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))
                # Compute total accuracy in the whole batch and add to train_acc
                val_acc += acc.item()
                print("Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

        epoch_val_loss = val_loss / len(dataloader_eval)
        val_losses.append(epoch_val_loss)
        print(f"Epoch Validation Loss: {epoch_val_loss:.4f}")

        epoch_val_acc = val_acc / len(dataloader_eval)
        val_accuracies.append(epoch_val_acc)
        print(f"Epoch Validation Accuracy: {epoch_val_acc:.4f}")

        precision, recall, fscore, _ = precision_recall_fscore_support(val_labels, val_predictions, average="weighted", zero_division=np.nan)
        print(f"Accuracy: {epoch_val_acc} | Precision: {precision} | Recall: {recall} | F1: {fscore} | Avg Loss: {epoch_val_loss}")
# Out:
# Epoch: 1/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.7072, Accuracy: 0.3750
# Batch number: 001, Training: Loss: 0.7015, Accuracy: 0.4375
# Batch number: 002, Training: Loss: 0.6879, Accuracy: 0.5938
# Batch number: 003, Training: Loss: 0.6954, Accuracy: 0.4688
# Batch number: 004, Training: Loss: 0.6821, Accuracy: 0.6250
# Batch number: 005, Training: Loss: 0.7062, Accuracy: 0.5312
# Batch number: 006, Training: Loss: 0.6721, Accuracy: 0.6562
# Batch number: 007, Training: Loss: 0.6640, Accuracy: 0.7188
# Batch number: 008, Training: Loss: 0.6519, Accuracy: 0.6875
# Batch number: 009, Training: Loss: 0.6715, Accuracy: 0.7188
# Batch number: 010, Training: Loss: 0.6604, Accuracy: 0.6875
# Batch number: 011, Training: Loss: 0.6532, Accuracy: 0.6562
# Batch number: 012, Training: Loss: 0.6236, Accuracy: 0.8125
# Batch number: 013, Training: Loss: 0.6583, Accuracy: 0.7188
# Batch number: 014, Training: Loss: 0.6467, Accuracy: 0.6875
# Batch number: 015, Training: Loss: 0.6491, Accuracy: 0.6875
# Batch number: 016, Training: Loss: 0.5975, Accuracy: 0.7500
# Batch number: 017, Training: Loss: 0.7332, Accuracy: 0.5000
# Epoch Training Loss: 0.6701
# Epoch Training Accuracy: 0.6285
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.6664, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.6729, Accuracy: 0.6250
# Batch number: 002, Validation: Loss: 0.6826, Accuracy: 0.5714
# Epoch Validation Loss: 0.6740
# Epoch Validation Accuracy: 0.6801
# Accuracy: 0.680059532324473 | Precision: 0.6835452853598014 | Recall: 0.7051282051282052 | F1: 0.6913992208109855 | Avg Loss: 0.6739646196365356
# Epoch: 2/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.6479, Accuracy: 0.5625
# Batch number: 001, Training: Loss: 0.5681, Accuracy: 0.8125
# Batch number: 002, Training: Loss: 0.5793, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.5978, Accuracy: 0.7500
# Batch number: 004, Training: Loss: 0.6258, Accuracy: 0.6875
# Batch number: 005, Training: Loss: 0.6102, Accuracy: 0.7188
# Batch number: 006, Training: Loss: 0.5983, Accuracy: 0.7500
# Batch number: 007, Training: Loss: 0.5685, Accuracy: 0.7812
# Batch number: 008, Training: Loss: 0.6009, Accuracy: 0.7188
# Batch number: 009, Training: Loss: 0.5208, Accuracy: 0.8438
# Batch number: 010, Training: Loss: 0.5813, Accuracy: 0.7188
# Batch number: 011, Training: Loss: 0.5883, Accuracy: 0.7188
# Batch number: 012, Training: Loss: 0.5630, Accuracy: 0.7500
# Batch number: 013, Training: Loss: 0.5782, Accuracy: 0.7500
# Batch number: 014, Training: Loss: 0.5639, Accuracy: 0.7188
# Batch number: 015, Training: Loss: 0.6605, Accuracy: 0.5938
# Batch number: 016, Training: Loss: 0.6178, Accuracy: 0.6875
# Batch number: 017, Training: Loss: 0.4036, Accuracy: 1.0000
# Epoch Training Loss: 0.5819
# Epoch Training Accuracy: 0.7448
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.6260, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.6237, Accuracy: 0.8125
# Batch number: 002, Validation: Loss: 0.6595, Accuracy: 0.6429
# Epoch Validation Loss: 0.6364
# Epoch Validation Accuracy: 0.7455
# Accuracy: 0.7455357114473978 | Precision: 0.7759747102212856 | Recall: 0.7692307692307693 | F1: 0.7124260355029586 | Avg Loss: 0.6364173094431559
# Epoch: 3/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.6489, Accuracy: 0.6250
# Batch number: 001, Training: Loss: 0.5409, Accuracy: 0.7188
# Batch number: 002, Training: Loss: 0.5174, Accuracy: 0.8125
# Batch number: 003, Training: Loss: 0.5807, Accuracy: 0.7188
# Batch number: 004, Training: Loss: 0.5561, Accuracy: 0.7188
# Batch number: 005, Training: Loss: 0.5470, Accuracy: 0.7188
# Batch number: 006, Training: Loss: 0.6941, Accuracy: 0.5625
# Batch number: 007, Training: Loss: 0.6063, Accuracy: 0.6562
# Batch number: 008, Training: Loss: 0.5407, Accuracy: 0.7500
# Batch number: 009, Training: Loss: 0.5915, Accuracy: 0.6875
# Batch number: 010, Training: Loss: 0.5212, Accuracy: 0.7812
# Batch number: 011, Training: Loss: 0.4977, Accuracy: 0.7812
# Batch number: 012, Training: Loss: 0.5198, Accuracy: 0.7188
# Batch number: 013, Training: Loss: 0.4336, Accuracy: 0.8438
# Batch number: 014, Training: Loss: 0.5128, Accuracy: 0.7812
# Batch number: 015, Training: Loss: 0.5256, Accuracy: 0.7500
# Batch number: 016, Training: Loss: 0.4705, Accuracy: 0.7812
# Batch number: 017, Training: Loss: 0.2841, Accuracy: 1.0000
# Epoch Training Loss: 0.5327
# Epoch Training Accuracy: 0.7448
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5749, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.5886, Accuracy: 0.7500
# Batch number: 002, Validation: Loss: 0.6627, Accuracy: 0.6429
# Epoch Validation Loss: 0.6087
# Epoch Validation Accuracy: 0.7247
# Accuracy: 0.7247023781140646 | Precision: 0.7251282051282052 | Recall: 0.7435897435897436 | F1: 0.664918414918415 | Avg Loss: 0.6087473630905151
# Epoch: 4/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.4719, Accuracy: 0.8125
# Batch number: 001, Training: Loss: 0.4370, Accuracy: 0.8125
# Batch number: 002, Training: Loss: 0.5044, Accuracy: 0.7500
# Batch number: 003, Training: Loss: 0.3957, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.6695, Accuracy: 0.6562
# Batch number: 005, Training: Loss: 0.5592, Accuracy: 0.7188
# Batch number: 006, Training: Loss: 0.4383, Accuracy: 0.7812
# Batch number: 007, Training: Loss: 0.5556, Accuracy: 0.7500
# Batch number: 008, Training: Loss: 0.7275, Accuracy: 0.5625
# Batch number: 009, Training: Loss: 0.5547, Accuracy: 0.6875
# Batch number: 010, Training: Loss: 0.4256, Accuracy: 0.8438
# Batch number: 011, Training: Loss: 0.4576, Accuracy: 0.7812
# Batch number: 012, Training: Loss: 0.5815, Accuracy: 0.6562
# Batch number: 013, Training: Loss: 0.5582, Accuracy: 0.6562
# Batch number: 014, Training: Loss: 0.5301, Accuracy: 0.7188
# Batch number: 015, Training: Loss: 0.6301, Accuracy: 0.6562
# Batch number: 016, Training: Loss: 0.5914, Accuracy: 0.6875
# Batch number: 017, Training: Loss: 0.2312, Accuracy: 1.0000
# Epoch Training Loss: 0.5178
# Epoch Training Accuracy: 0.7448
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5299, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.5647, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.6083, Accuracy: 0.6429
# Epoch Validation Loss: 0.5676
# Epoch Validation Accuracy: 0.7351
# Accuracy: 0.7351190447807312 | Precision: 0.8173076923076923 | Recall: 0.7564102564102564 | F1: 0.6731963688485427 | Avg Loss: 0.5676266153653463
# Epoch: 5/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.4842, Accuracy: 0.7188
# Batch number: 001, Training: Loss: 0.4841, Accuracy: 0.6875
# Batch number: 002, Training: Loss: 0.4646, Accuracy: 0.7812
# Batch number: 003, Training: Loss: 0.4983, Accuracy: 0.7500
# Batch number: 004, Training: Loss: 0.6143, Accuracy: 0.6562
# Batch number: 005, Training: Loss: 0.5609, Accuracy: 0.7188
# Batch number: 006, Training: Loss: 0.3605, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.4782, Accuracy: 0.6875
# Batch number: 008, Training: Loss: 0.4108, Accuracy: 0.8438
# Batch number: 009, Training: Loss: 0.5130, Accuracy: 0.6875
# Batch number: 010, Training: Loss: 0.4229, Accuracy: 0.7812
# Batch number: 011, Training: Loss: 0.4844, Accuracy: 0.6875
# Batch number: 012, Training: Loss: 0.4631, Accuracy: 0.7500
# Batch number: 013, Training: Loss: 0.6775, Accuracy: 0.6562
# Batch number: 014, Training: Loss: 0.5165, Accuracy: 0.7188
# Batch number: 015, Training: Loss: 0.6187, Accuracy: 0.6875
# Batch number: 016, Training: Loss: 0.4859, Accuracy: 0.7812
# Batch number: 017, Training: Loss: 0.2018, Accuracy: 1.0000
# Epoch Training Loss: 0.4856
# Epoch Training Accuracy: 0.7465
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5232, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.5657, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.5801, Accuracy: 0.6429
# Epoch Validation Loss: 0.5563
# Epoch Validation Accuracy: 0.7351
# Accuracy: 0.7351190447807312 | Precision: 0.8173076923076923 | Recall: 0.7564102564102564 | F1: 0.6731963688485427 | Avg Loss: 0.5563243627548218
# Epoch: 6/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.4699, Accuracy: 0.7500
# Batch number: 001, Training: Loss: 0.4604, Accuracy: 0.7500
# Batch number: 002, Training: Loss: 0.4111, Accuracy: 0.7812
# Batch number: 003, Training: Loss: 0.5771, Accuracy: 0.6250
# Batch number: 004, Training: Loss: 0.3602, Accuracy: 0.7812
# Batch number: 005, Training: Loss: 0.3456, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.4425, Accuracy: 0.7812
# Batch number: 007, Training: Loss: 0.5084, Accuracy: 0.7188
# Batch number: 008, Training: Loss: 0.4574, Accuracy: 0.7188
# Batch number: 009, Training: Loss: 0.4767, Accuracy: 0.7188
# Batch number: 010, Training: Loss: 0.5977, Accuracy: 0.7188
# Batch number: 011, Training: Loss: 0.6215, Accuracy: 0.6250
# Batch number: 012, Training: Loss: 0.4279, Accuracy: 0.7188
# Batch number: 013, Training: Loss: 0.3769, Accuracy: 0.7812
# Batch number: 014, Training: Loss: 0.5632, Accuracy: 0.6562
# Batch number: 015, Training: Loss: 0.5544, Accuracy: 0.7188
# Batch number: 016, Training: Loss: 0.3767, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 1.6937, Accuracy: 0.0000
# Epoch Training Loss: 0.5401
# Epoch Training Accuracy: 0.6962
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5139, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.5588, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.5510, Accuracy: 0.6429
# Epoch Validation Loss: 0.5412
# Epoch Validation Accuracy: 0.7664
# Accuracy: 0.7663690447807312 | Precision: 0.839831401475237 | Recall: 0.7948717948717948 | F1: 0.744378698224852 | Avg Loss: 0.5412367184956869
# Epoch: 7/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3944, Accuracy: 0.8438
# Batch number: 001, Training: Loss: 0.6146, Accuracy: 0.6875
# Batch number: 002, Training: Loss: 0.3981, Accuracy: 0.7812
# Batch number: 003, Training: Loss: 0.4879, Accuracy: 0.6875
# Batch number: 004, Training: Loss: 0.5581, Accuracy: 0.7188
# Batch number: 005, Training: Loss: 0.4605, Accuracy: 0.7812
# Batch number: 006, Training: Loss: 0.4345, Accuracy: 0.7500
# Batch number: 007, Training: Loss: 0.5130, Accuracy: 0.6250
# Batch number: 008, Training: Loss: 0.3838, Accuracy: 0.7812
# Batch number: 009, Training: Loss: 0.5185, Accuracy: 0.6875
# Batch number: 010, Training: Loss: 0.4448, Accuracy: 0.7812
# Batch number: 011, Training: Loss: 0.4111, Accuracy: 0.7500
# Batch number: 012, Training: Loss: 0.3558, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.3488, Accuracy: 0.8750
# Batch number: 014, Training: Loss: 0.5335, Accuracy: 0.7188
# Batch number: 015, Training: Loss: 0.5280, Accuracy: 0.6875
# Batch number: 016, Training: Loss: 0.6026, Accuracy: 0.6250
# Batch number: 017, Training: Loss: 0.6461, Accuracy: 0.5000
# Epoch Training Loss: 0.4797
# Epoch Training Accuracy: 0.7326
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4982, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.5524, Accuracy: 0.8125
# Batch number: 002, Validation: Loss: 0.5619, Accuracy: 0.6429
# Epoch Validation Loss: 0.5375
# Epoch Validation Accuracy: 0.7664
# Accuracy: 0.7663690447807312 | Precision: 0.8071505958829902 | Recall: 0.7948717948717948 | F1: 0.7548076923076923 | Avg Loss: 0.5375071366628011
# Epoch: 8/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.4614, Accuracy: 0.8125
# Batch number: 001, Training: Loss: 0.3574, Accuracy: 0.8438
# Batch number: 002, Training: Loss: 0.3467, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.4776, Accuracy: 0.7500
# Batch number: 004, Training: Loss: 0.5590, Accuracy: 0.7500
# Batch number: 005, Training: Loss: 0.4388, Accuracy: 0.7188
# Batch number: 006, Training: Loss: 0.6041, Accuracy: 0.6875
# Batch number: 007, Training: Loss: 0.4464, Accuracy: 0.7188
# Batch number: 008, Training: Loss: 0.4376, Accuracy: 0.7812
# Batch number: 009, Training: Loss: 0.4711, Accuracy: 0.6875
# Batch number: 010, Training: Loss: 0.6531, Accuracy: 0.5625
# Batch number: 011, Training: Loss: 0.4806, Accuracy: 0.7812
# Batch number: 012, Training: Loss: 0.5332, Accuracy: 0.7188
# Batch number: 013, Training: Loss: 0.3454, Accuracy: 0.8438
# Batch number: 014, Training: Loss: 0.4783, Accuracy: 0.7812
# Batch number: 015, Training: Loss: 0.4491, Accuracy: 0.8125
# Batch number: 016, Training: Loss: 0.3640, Accuracy: 0.8750
# Batch number: 017, Training: Loss: 0.2784, Accuracy: 1.0000
# Epoch Training Loss: 0.4546
# Epoch Training Accuracy: 0.7760
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4772, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.5336, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.5517, Accuracy: 0.7143
# Epoch Validation Loss: 0.5208
# Epoch Validation Accuracy: 0.8006
# Accuracy: 0.800595243771871 | Precision: 0.8324043106651803 | Recall: 0.8205128205128205 | F1: 0.7931623931623931 | Avg Loss: 0.5208457310994467
# Epoch: 9/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.4766, Accuracy: 0.6875
# Batch number: 001, Training: Loss: 0.7649, Accuracy: 0.6250
# Batch number: 002, Training: Loss: 0.4855, Accuracy: 0.7188
# Batch number: 003, Training: Loss: 0.3755, Accuracy: 0.8125
# Batch number: 004, Training: Loss: 0.4430, Accuracy: 0.6875
# Batch number: 005, Training: Loss: 0.3149, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.3884, Accuracy: 0.7812
# Batch number: 007, Training: Loss: 0.4260, Accuracy: 0.8438
# Batch number: 008, Training: Loss: 0.4803, Accuracy: 0.7500
# Batch number: 009, Training: Loss: 0.5400, Accuracy: 0.7812
# Batch number: 010, Training: Loss: 0.3533, Accuracy: 0.8125
# Batch number: 011, Training: Loss: 0.4095, Accuracy: 0.8125
# Batch number: 012, Training: Loss: 0.3039, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.5185, Accuracy: 0.8125
# Batch number: 014, Training: Loss: 0.4492, Accuracy: 0.7812
# Batch number: 015, Training: Loss: 0.5029, Accuracy: 0.7188
# Batch number: 016, Training: Loss: 0.3303, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 0.1787, Accuracy: 1.0000
# Epoch Training Loss: 0.4301
# Epoch Training Accuracy: 0.7969
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4485, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.5058, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.5812, Accuracy: 0.7143
# Epoch Validation Loss: 0.5119
# Epoch Validation Accuracy: 0.8006
# Accuracy: 0.800595243771871 | Precision: 0.8324043106651803 | Recall: 0.8205128205128205 | F1: 0.7931623931623931 | Avg Loss: 0.5118592580159506
# Epoch: 10/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.4756, Accuracy: 0.8750
# Batch number: 001, Training: Loss: 0.4327, Accuracy: 0.7812
# Batch number: 002, Training: Loss: 0.5734, Accuracy: 0.6875
# Batch number: 003, Training: Loss: 0.3695, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.4349, Accuracy: 0.6875
# Batch number: 005, Training: Loss: 0.2870, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.4031, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.4240, Accuracy: 0.8125
# Batch number: 008, Training: Loss: 0.3659, Accuracy: 0.8438
# Batch number: 009, Training: Loss: 0.4354, Accuracy: 0.8125
# Batch number: 010, Training: Loss: 0.5055, Accuracy: 0.6562
# Batch number: 011, Training: Loss: 0.4420, Accuracy: 0.7812
# Batch number: 012, Training: Loss: 0.5605, Accuracy: 0.7500
# Batch number: 013, Training: Loss: 0.2841, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.5234, Accuracy: 0.7188
# Batch number: 015, Training: Loss: 0.4414, Accuracy: 0.7812
# Batch number: 016, Training: Loss: 0.4506, Accuracy: 0.7500
# Batch number: 017, Training: Loss: 0.2778, Accuracy: 1.0000
# Epoch Training Loss: 0.4271
# Epoch Training Accuracy: 0.8090
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4419, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.4790, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.6092, Accuracy: 0.7143
# Epoch Validation Loss: 0.5100
# Epoch Validation Accuracy: 0.7902
# Accuracy: 0.7901785771052042 | Precision: 0.8477564102564102 | Recall: 0.8076923076923077 | F1: 0.7654541840588351 | Avg Loss: 0.5100305875142416
# Epoch: 11/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3025, Accuracy: 0.8750
# Batch number: 001, Training: Loss: 0.2779, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.4404, Accuracy: 0.8125
# Batch number: 003, Training: Loss: 0.3964, Accuracy: 0.7188
# Batch number: 004, Training: Loss: 0.3023, Accuracy: 0.8750
# Batch number: 005, Training: Loss: 0.3584, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.4888, Accuracy: 0.7812
# Batch number: 007, Training: Loss: 0.3111, Accuracy: 0.8438
# Batch number: 008, Training: Loss: 0.5290, Accuracy: 0.7812
# Batch number: 009, Training: Loss: 0.4228, Accuracy: 0.7812
# Batch number: 010, Training: Loss: 0.3837, Accuracy: 0.8125
# Batch number: 011, Training: Loss: 0.5089, Accuracy: 0.7500
# Batch number: 012, Training: Loss: 0.3985, Accuracy: 0.8125
# Batch number: 013, Training: Loss: 0.3324, Accuracy: 0.8438
# Batch number: 014, Training: Loss: 0.5351, Accuracy: 0.7812
# Batch number: 015, Training: Loss: 0.6258, Accuracy: 0.6250
# Batch number: 016, Training: Loss: 0.4189, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 2.2321, Accuracy: 0.5000
# Epoch Training Loss: 0.5147
# Epoch Training Accuracy: 0.7882
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4336, Accuracy: 0.7500
# Batch number: 001, Validation: Loss: 0.5075, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.7155, Accuracy: 0.7143
# Epoch Validation Loss: 0.5522
# Epoch Validation Accuracy: 0.7693
# Accuracy: 0.769345243771871 | Precision: 0.7760989010989011 | Recall: 0.782051282051282 | F1: 0.744355562981683 | Avg Loss: 0.5521938304106394
# Epoch: 12/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3824, Accuracy: 0.8125
# Batch number: 001, Training: Loss: 0.3407, Accuracy: 0.8125
# Batch number: 002, Training: Loss: 0.3193, Accuracy: 0.9688
# Batch number: 003, Training: Loss: 0.6090, Accuracy: 0.6562
# Batch number: 004, Training: Loss: 0.4058, Accuracy: 0.7812
# Batch number: 005, Training: Loss: 0.3687, Accuracy: 0.8438
# Batch number: 006, Training: Loss: 0.4250, Accuracy: 0.8125
# Batch number: 007, Training: Loss: 0.3468, Accuracy: 0.8750
# Batch number: 008, Training: Loss: 0.4376, Accuracy: 0.7812
# Batch number: 009, Training: Loss: 0.3695, Accuracy: 0.7500
# Batch number: 010, Training: Loss: 0.3853, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.5146, Accuracy: 0.8125
# Batch number: 012, Training: Loss: 0.3285, Accuracy: 0.8438
# Batch number: 013, Training: Loss: 0.3316, Accuracy: 0.8438
# Batch number: 014, Training: Loss: 0.3763, Accuracy: 0.8438
# Batch number: 015, Training: Loss: 0.4752, Accuracy: 0.7188
# Batch number: 016, Training: Loss: 0.5546, Accuracy: 0.7188
# Batch number: 017, Training: Loss: 0.5598, Accuracy: 0.5000
# Epoch Training Loss: 0.4184
# Epoch Training Accuracy: 0.7917
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4239, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.5034, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.7351, Accuracy: 0.7857
# Epoch Validation Loss: 0.5541
# Epoch Validation Accuracy: 0.8140
# Accuracy: 0.8139880895614624 | Precision: 0.8201649097171486 | Recall: 0.8205128205128205 | F1: 0.799705334987593 | Avg Loss: 0.5541423757870992
# Epoch: 13/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3376, Accuracy: 0.8750
# Batch number: 001, Training: Loss: 0.3812, Accuracy: 0.8125
# Batch number: 002, Training: Loss: 0.3804, Accuracy: 0.8750
# Batch number: 003, Training: Loss: 0.4819, Accuracy: 0.8438
# Batch number: 004, Training: Loss: 0.3322, Accuracy: 0.8750
# Batch number: 005, Training: Loss: 0.5996, Accuracy: 0.6875
# Batch number: 006, Training: Loss: 0.6927, Accuracy: 0.7500
# Batch number: 007, Training: Loss: 0.2980, Accuracy: 0.8750
# Batch number: 008, Training: Loss: 0.3305, Accuracy: 0.8750
# Batch number: 009, Training: Loss: 0.3842, Accuracy: 0.7812
# Batch number: 010, Training: Loss: 0.5495, Accuracy: 0.7500
# Batch number: 011, Training: Loss: 0.3607, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.4025, Accuracy: 0.8750
# Batch number: 013, Training: Loss: 0.2713, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.3985, Accuracy: 0.8438
# Batch number: 015, Training: Loss: 0.4207, Accuracy: 0.7812
# Batch number: 016, Training: Loss: 0.4271, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 1.5332, Accuracy: 0.5000
# Epoch Training Loss: 0.4768
# Epoch Training Accuracy: 0.8160
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4216, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.5069, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.7056, Accuracy: 0.7857
# Epoch Validation Loss: 0.5447
# Epoch Validation Accuracy: 0.8140
# Accuracy: 0.8139880895614624 | Precision: 0.8142011834319527 | Recall: 0.8205128205128205 | F1: 0.8052815073065797 | Avg Loss: 0.5446927746136984
# Epoch: 14/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.5231, Accuracy: 0.7500
# Batch number: 001, Training: Loss: 0.5258, Accuracy: 0.8125
# Batch number: 002, Training: Loss: 0.3996, Accuracy: 0.8125
# Batch number: 003, Training: Loss: 0.3024, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.4430, Accuracy: 0.8438
# Batch number: 005, Training: Loss: 0.3901, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.3343, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.3461, Accuracy: 0.8750
# Batch number: 008, Training: Loss: 0.3461, Accuracy: 0.8438
# Batch number: 009, Training: Loss: 0.4063, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.4298, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.2854, Accuracy: 0.9688
# Batch number: 012, Training: Loss: 0.4297, Accuracy: 0.8438
# Batch number: 013, Training: Loss: 0.4090, Accuracy: 0.8438
# Batch number: 014, Training: Loss: 0.4466, Accuracy: 0.7812
# Batch number: 015, Training: Loss: 0.3829, Accuracy: 0.8438
# Batch number: 016, Training: Loss: 0.4857, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 0.1818, Accuracy: 1.0000
# Epoch Training Loss: 0.3927
# Epoch Training Accuracy: 0.8576
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4295, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.5317, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.7075, Accuracy: 0.7857
# Epoch Validation Loss: 0.5563
# Epoch Validation Accuracy: 0.7827
# Accuracy: 0.7827380895614624 | Precision: 0.7668269230769231 | Recall: 0.782051282051282 | F1: 0.7665607120152574 | Avg Loss: 0.5562500059604645
# Epoch: 15/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3122, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.3496, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.3472, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.2661, Accuracy: 0.9688
# Batch number: 004, Training: Loss: 0.3194, Accuracy: 0.9062
# Batch number: 005, Training: Loss: 0.3339, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.3849, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.3566, Accuracy: 0.8125
# Batch number: 008, Training: Loss: 0.4111, Accuracy: 0.8438
# Batch number: 009, Training: Loss: 0.2591, Accuracy: 0.9375
# Batch number: 010, Training: Loss: 0.4739, Accuracy: 0.7500
# Batch number: 011, Training: Loss: 0.5473, Accuracy: 0.6875
# Batch number: 012, Training: Loss: 0.2790, Accuracy: 0.9688
# Batch number: 013, Training: Loss: 0.4771, Accuracy: 0.7188
# Batch number: 014, Training: Loss: 0.4951, Accuracy: 0.8438
# Batch number: 015, Training: Loss: 0.3558, Accuracy: 0.8438
# Batch number: 016, Training: Loss: 0.4292, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 0.5257, Accuracy: 0.5000
# Epoch Training Loss: 0.3846
# Epoch Training Accuracy: 0.8368
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4226, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.5214, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.6725, Accuracy: 0.7143
# Epoch Validation Loss: 0.5388
# Epoch Validation Accuracy: 0.7589
# Accuracy: 0.7589285771052042 | Precision: 0.7531135531135532 | Recall: 0.7692307692307693 | F1: 0.7557692307692307 | Avg Loss: 0.5388446847597758
# Epoch: 16/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.4543, Accuracy: 0.8438
# Batch number: 001, Training: Loss: 0.4068, Accuracy: 0.8125
# Batch number: 002, Training: Loss: 0.3562, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.3185, Accuracy: 0.8438
# Batch number: 004, Training: Loss: 0.3048, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.3148, Accuracy: 0.8438
# Batch number: 006, Training: Loss: 0.3324, Accuracy: 0.9062
# Batch number: 007, Training: Loss: 0.3044, Accuracy: 0.8438
# Batch number: 008, Training: Loss: 0.6257, Accuracy: 0.7188
# Batch number: 009, Training: Loss: 0.4155, Accuracy: 0.7812
# Batch number: 010, Training: Loss: 0.2692, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.3218, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.3562, Accuracy: 0.8438
# Batch number: 013, Training: Loss: 0.3212, Accuracy: 0.8750
# Batch number: 014, Training: Loss: 0.3928, Accuracy: 0.8438
# Batch number: 015, Training: Loss: 0.2467, Accuracy: 0.9375
# Batch number: 016, Training: Loss: 0.3507, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 1.3077, Accuracy: 0.5000
# Epoch Training Loss: 0.4111
# Epoch Training Accuracy: 0.8368
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4000, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.5366, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.6646, Accuracy: 0.6429
# Epoch Validation Loss: 0.5337
# Epoch Validation Accuracy: 0.7351
# Accuracy: 0.7351190447807312 | Precision: 0.7407723325062034 | Recall: 0.7564102564102564 | F1: 0.7450689215395098 | Avg Loss: 0.5337362786134084
# Epoch: 17/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.4941, Accuracy: 0.7500
# Batch number: 001, Training: Loss: 0.2929, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.3468, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.3458, Accuracy: 0.8438
# Batch number: 004, Training: Loss: 0.2934, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.3924, Accuracy: 0.8125
# Batch number: 006, Training: Loss: 0.3548, Accuracy: 0.8125
# Batch number: 007, Training: Loss: 0.3170, Accuracy: 0.8750
# Batch number: 008, Training: Loss: 0.3352, Accuracy: 0.8750
# Batch number: 009, Training: Loss: 0.5235, Accuracy: 0.7500
# Batch number: 010, Training: Loss: 0.3221, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.3639, Accuracy: 0.8750
# Batch number: 012, Training: Loss: 0.3212, Accuracy: 0.8125
# Batch number: 013, Training: Loss: 0.4713, Accuracy: 0.8438
# Batch number: 014, Training: Loss: 0.3958, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.3776, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.2401, Accuracy: 0.9375
# Batch number: 017, Training: Loss: 0.4085, Accuracy: 0.5000
# Epoch Training Loss: 0.3665
# Epoch Training Accuracy: 0.8351
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3808, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.5449, Accuracy: 0.8125
# Batch number: 002, Validation: Loss: 0.6672, Accuracy: 0.6429
# Epoch Validation Loss: 0.5309
# Epoch Validation Accuracy: 0.7664
# Accuracy: 0.7663690447807312 | Precision: 0.7851791410132779 | Recall: 0.7948717948717948 | F1: 0.7875523227887189 | Avg Loss: 0.5309492349624634
# Epoch: 18/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.5063, Accuracy: 0.8125
# Batch number: 001, Training: Loss: 0.3207, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.3284, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.3144, Accuracy: 0.8438
# Batch number: 004, Training: Loss: 0.2604, Accuracy: 0.9062
# Batch number: 005, Training: Loss: 0.2896, Accuracy: 0.8125
# Batch number: 006, Training: Loss: 0.2831, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.3030, Accuracy: 0.8438
# Batch number: 008, Training: Loss: 0.5406, Accuracy: 0.6250
# Batch number: 009, Training: Loss: 0.2965, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.2074, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.5299, Accuracy: 0.8750
# Batch number: 012, Training: Loss: 0.3085, Accuracy: 0.8438
# Batch number: 013, Training: Loss: 0.3524, Accuracy: 0.8750
# Batch number: 014, Training: Loss: 0.2262, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.3109, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.3182, Accuracy: 0.8438
# Batch number: 017, Training: Loss: 0.1101, Accuracy: 1.0000
# Epoch Training Loss: 0.3226
# Epoch Training Accuracy: 0.8663
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3752, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.5634, Accuracy: 0.7500
# Batch number: 002, Validation: Loss: 0.6650, Accuracy: 0.6429
# Epoch Validation Loss: 0.5345
# Epoch Validation Accuracy: 0.7351
# Accuracy: 0.7351190447807312 | Precision: 0.7463675213675214 | Recall: 0.7564102564102564 | F1: 0.7501643655489809 | Avg Loss: 0.5345220963160197
# Epoch: 19/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3567, Accuracy: 0.8125
# Batch number: 001, Training: Loss: 0.5726, Accuracy: 0.8750
# Batch number: 002, Training: Loss: 0.3115, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.2444, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.3208, Accuracy: 0.8750
# Batch number: 005, Training: Loss: 0.1970, Accuracy: 0.9688
# Batch number: 006, Training: Loss: 0.3913, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.3903, Accuracy: 0.8438
# Batch number: 008, Training: Loss: 0.1996, Accuracy: 0.9375
# Batch number: 009, Training: Loss: 0.3508, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.3369, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.2334, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.4114, Accuracy: 0.8438
# Batch number: 013, Training: Loss: 0.2150, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.2888, Accuracy: 0.8750
# Batch number: 015, Training: Loss: 0.2745, Accuracy: 0.8125
# Batch number: 016, Training: Loss: 0.4768, Accuracy: 0.7812
# Batch number: 017, Training: Loss: 0.2097, Accuracy: 1.0000
# Epoch Training Loss: 0.3212
# Epoch Training Accuracy: 0.8837
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3832, Accuracy: 0.8750
# Batch number: 001, Validation: Loss: 0.5467, Accuracy: 0.7500
# Batch number: 002, Validation: Loss: 0.5804, Accuracy: 0.6429
# Epoch Validation Loss: 0.5035
# Epoch Validation Accuracy: 0.7560
# Accuracy: 0.7559523781140646 | Precision: 0.7789124668435013 | Recall: 0.782051282051282 | F1: 0.7803409739783016 | Avg Loss: 0.5034525295098623
# Epoch: 20/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3840, Accuracy: 0.7500
# Batch number: 001, Training: Loss: 0.2213, Accuracy: 0.9688
# Batch number: 002, Training: Loss: 0.4080, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.3368, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.5999, Accuracy: 0.6875
# Batch number: 005, Training: Loss: 0.3214, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.3116, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.2194, Accuracy: 0.9375
# Batch number: 008, Training: Loss: 0.1685, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.3565, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.1777, Accuracy: 0.9688
# Batch number: 011, Training: Loss: 0.1652, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.2508, Accuracy: 0.8750
# Batch number: 013, Training: Loss: 0.3631, Accuracy: 0.8750
# Batch number: 014, Training: Loss: 0.3661, Accuracy: 0.8438
# Batch number: 015, Training: Loss: 0.2818, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.3299, Accuracy: 0.8438
# Batch number: 017, Training: Loss: 0.1001, Accuracy: 1.0000
# Epoch Training Loss: 0.2979
# Epoch Training Accuracy: 0.8802
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4085, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.5416, Accuracy: 0.7500
# Batch number: 002, Validation: Loss: 0.5120, Accuracy: 0.7857
# Epoch Validation Loss: 0.4874
# Epoch Validation Accuracy: 0.7827
# Accuracy: 0.7827380895614624 | Precision: 0.7789124668435013 | Recall: 0.782051282051282 | F1: 0.7803409739783016 | Avg Loss: 0.48736493786176044
# Epoch: 21/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.2596, Accuracy: 0.9375
# Batch number: 001, Training: Loss: 0.1656, Accuracy: 0.9688
# Batch number: 002, Training: Loss: 0.3081, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.2512, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.3141, Accuracy: 0.9062
# Batch number: 005, Training: Loss: 0.3031, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.3009, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.3004, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.3032, Accuracy: 0.8750
# Batch number: 009, Training: Loss: 0.2932, Accuracy: 0.8438
# Batch number: 010, Training: Loss: 0.1838, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.2071, Accuracy: 0.9688
# Batch number: 012, Training: Loss: 0.3115, Accuracy: 0.8750
# Batch number: 013, Training: Loss: 0.2503, Accuracy: 0.9062
# Batch number: 014, Training: Loss: 0.3455, Accuracy: 0.8125
# Batch number: 015, Training: Loss: 0.3466, Accuracy: 0.8125
# Batch number: 016, Training: Loss: 0.2275, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 0.1967, Accuracy: 1.0000
# Epoch Training Loss: 0.2705
# Epoch Training Accuracy: 0.8993
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4495, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.5755, Accuracy: 0.7500
# Batch number: 002, Validation: Loss: 0.4660, Accuracy: 0.8571
# Epoch Validation Loss: 0.4970
# Epoch Validation Accuracy: 0.8065
# Accuracy: 0.8065476218859354 | Precision: 0.7948717948717948 | Recall: 0.7948717948717948 | F1: 0.7948717948717948 | Avg Loss: 0.4970056116580963
# Epoch: 22/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.1912, Accuracy: 0.9375
# Batch number: 001, Training: Loss: 0.2651, Accuracy: 0.8750
# Batch number: 002, Training: Loss: 0.1837, Accuracy: 0.9688
# Batch number: 003, Training: Loss: 0.1465, Accuracy: 1.0000
# Batch number: 004, Training: Loss: 0.3187, Accuracy: 0.8125
# Batch number: 005, Training: Loss: 0.4962, Accuracy: 0.7812
# Batch number: 006, Training: Loss: 0.3366, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.3191, Accuracy: 0.8438
# Batch number: 008, Training: Loss: 0.2441, Accuracy: 0.9375
# Batch number: 009, Training: Loss: 0.4178, Accuracy: 0.8125
# Batch number: 010, Training: Loss: 0.3187, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.3228, Accuracy: 0.8438
# Batch number: 012, Training: Loss: 0.2979, Accuracy: 0.8125
# Batch number: 013, Training: Loss: 0.3367, Accuracy: 0.8125
# Batch number: 014, Training: Loss: 0.1598, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.2637, Accuracy: 0.9375
# Batch number: 016, Training: Loss: 0.2559, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 1.0135, Accuracy: 0.5000
# Epoch Training Loss: 0.3271
# Epoch Training Accuracy: 0.8594
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5000, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.6406, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.4830, Accuracy: 0.8571
# Epoch Validation Loss: 0.5412
# Epoch Validation Accuracy: 0.8065
# Accuracy: 0.8065476218859354 | Precision: 0.8016418364244452 | Recall: 0.7948717948717948 | F1: 0.7977022977022977 | Avg Loss: 0.5411738952000936
# Epoch: 23/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3561, Accuracy: 0.8438
# Batch number: 001, Training: Loss: 0.2141, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.2069, Accuracy: 0.9375
# Batch number: 003, Training: Loss: 0.1093, Accuracy: 0.9688
# Batch number: 004, Training: Loss: 0.3172, Accuracy: 0.8750
# Batch number: 005, Training: Loss: 0.3805, Accuracy: 0.8438
# Batch number: 006, Training: Loss: 0.1763, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.2144, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.2678, Accuracy: 0.9062
# Batch number: 009, Training: Loss: 0.3267, Accuracy: 0.8125
# Batch number: 010, Training: Loss: 0.2380, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.1952, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.5565, Accuracy: 0.8125
# Batch number: 013, Training: Loss: 0.3968, Accuracy: 0.7812
# Batch number: 014, Training: Loss: 0.2552, Accuracy: 0.8750
# Batch number: 015, Training: Loss: 0.3622, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.2102, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 0.1629, Accuracy: 1.0000
# Epoch Training Loss: 0.2748
# Epoch Training Accuracy: 0.8889
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4395, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.5680, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.4448, Accuracy: 0.8571
# Epoch Validation Loss: 0.4841
# Epoch Validation Accuracy: 0.8378
# Accuracy: 0.8377976218859354 | Precision: 0.8277777777777777 | Recall: 0.8333333333333334 | F1: 0.8290598290598289 | Avg Loss: 0.48412707448005676
# Epoch: 24/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3700, Accuracy: 0.7812
# Batch number: 001, Training: Loss: 0.2861, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.4271, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.1508, Accuracy: 0.9688
# Batch number: 004, Training: Loss: 0.2452, Accuracy: 0.9062
# Batch number: 005, Training: Loss: 0.2811, Accuracy: 0.8438
# Batch number: 006, Training: Loss: 0.2531, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.3974, Accuracy: 0.8125
# Batch number: 008, Training: Loss: 0.2841, Accuracy: 0.8438
# Batch number: 009, Training: Loss: 0.2314, Accuracy: 0.9062
# Batch number: 010, Training: Loss: 0.3046, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.3012, Accuracy: 0.8438
# Batch number: 012, Training: Loss: 0.1685, Accuracy: 0.9688
# Batch number: 013, Training: Loss: 0.2096, Accuracy: 0.9062
# Batch number: 014, Training: Loss: 0.1559, Accuracy: 0.9688
# Batch number: 015, Training: Loss: 0.1710, Accuracy: 0.9375
# Batch number: 016, Training: Loss: 0.2445, Accuracy: 0.9375
# Batch number: 017, Training: Loss: 0.1323, Accuracy: 1.0000
# Epoch Training Loss: 0.2563
# Epoch Training Accuracy: 0.8941
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4100, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.5450, Accuracy: 0.8125
# Batch number: 002, Validation: Loss: 0.4455, Accuracy: 0.7857
# Epoch Validation Loss: 0.4669
# Epoch Validation Accuracy: 0.8140
# Accuracy: 0.8139880895614624 | Precision: 0.8129960685409094 | Recall: 0.8205128205128205 | F1: 0.814108282440129 | Avg Loss: 0.46686385075251263
# Epoch: 25/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.1603, Accuracy: 0.9375
# Batch number: 001, Training: Loss: 0.2797, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.4278, Accuracy: 0.8125
# Batch number: 003, Training: Loss: 0.3253, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.3838, Accuracy: 0.8438
# Batch number: 005, Training: Loss: 0.2122, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.2838, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.2800, Accuracy: 0.8750
# Batch number: 008, Training: Loss: 0.2384, Accuracy: 0.9062
# Batch number: 009, Training: Loss: 0.2676, Accuracy: 0.9062
# Batch number: 010, Training: Loss: 0.2438, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.1824, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.3120, Accuracy: 0.8438
# Batch number: 013, Training: Loss: 0.1674, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.1440, Accuracy: 0.9688
# Batch number: 015, Training: Loss: 0.2881, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.2059, Accuracy: 0.9375
# Batch number: 017, Training: Loss: 0.1028, Accuracy: 1.0000
# Epoch Training Loss: 0.2503
# Epoch Training Accuracy: 0.8993
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4093, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.5115, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.3884, Accuracy: 0.8571
# Epoch Validation Loss: 0.4364
# Epoch Validation Accuracy: 0.8482
# Accuracy: 0.8482142885526022 | Precision: 0.8408129960685409 | Recall: 0.8461538461538461 | F1: 0.8406642420915392 | Avg Loss: 0.43640872836112976
# Epoch: 26/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.1974, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.3187, Accuracy: 0.8750
# Batch number: 002, Training: Loss: 0.2239, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.2450, Accuracy: 0.9375
# Batch number: 004, Training: Loss: 0.3230, Accuracy: 0.8750
# Batch number: 005, Training: Loss: 0.2310, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.1566, Accuracy: 0.9062
# Batch number: 007, Training: Loss: 0.1078, Accuracy: 1.0000
# Batch number: 008, Training: Loss: 0.2658, Accuracy: 0.8750
# Batch number: 009, Training: Loss: 0.2350, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.1499, Accuracy: 0.9688
# Batch number: 011, Training: Loss: 0.1738, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.1941, Accuracy: 0.9375
# Batch number: 013, Training: Loss: 0.3620, Accuracy: 0.8438
# Batch number: 014, Training: Loss: 0.1829, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.3052, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.2863, Accuracy: 0.8438
# Batch number: 017, Training: Loss: 0.5985, Accuracy: 0.5000
# Epoch Training Loss: 0.2532
# Epoch Training Accuracy: 0.8854
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4659, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.5169, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.3299, Accuracy: 0.9286
# Epoch Validation Loss: 0.4375
# Epoch Validation Accuracy: 0.8720
# Accuracy: 0.8720238010088602 | Precision: 0.8587740384615384 | Recall: 0.8589743589743589 | F1: 0.848951048951049 | Avg Loss: 0.43753249446551007
# Epoch: 27/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.2412, Accuracy: 0.8750
# Batch number: 001, Training: Loss: 0.3494, Accuracy: 0.8750
# Batch number: 002, Training: Loss: 0.2178, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.1023, Accuracy: 1.0000
# Batch number: 004, Training: Loss: 0.2227, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.1491, Accuracy: 0.9688
# Batch number: 006, Training: Loss: 0.2321, Accuracy: 0.8750
# Batch number: 007, Training: Loss: 0.1953, Accuracy: 0.9375
# Batch number: 008, Training: Loss: 0.2691, Accuracy: 0.8750
# Batch number: 009, Training: Loss: 0.3761, Accuracy: 0.8438
# Batch number: 010, Training: Loss: 0.2260, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.1624, Accuracy: 0.9688
# Batch number: 012, Training: Loss: 0.3185, Accuracy: 0.8750
# Batch number: 013, Training: Loss: 0.3149, Accuracy: 0.8125
# Batch number: 014, Training: Loss: 0.1580, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.2557, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.1531, Accuracy: 0.9688
# Batch number: 017, Training: Loss: 0.0842, Accuracy: 1.0000
# Epoch Training Loss: 0.2238
# Epoch Training Accuracy: 0.9167
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4752, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.4911, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.3148, Accuracy: 0.8571
# Epoch Validation Loss: 0.4270
# Epoch Validation Accuracy: 0.8482
# Accuracy: 0.8482142885526022 | Precision: 0.8417582417582418 | Recall: 0.8461538461538461 | F1: 0.8371794871794873 | Avg Loss: 0.4270358582337697
# Epoch: 28/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3876, Accuracy: 0.8438
# Batch number: 001, Training: Loss: 0.3438, Accuracy: 0.8438
# Batch number: 002, Training: Loss: 0.2595, Accuracy: 0.8750
# Batch number: 003, Training: Loss: 0.5708, Accuracy: 0.7500
# Batch number: 004, Training: Loss: 0.1400, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.2395, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.2823, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.3467, Accuracy: 0.8125
# Batch number: 008, Training: Loss: 0.3187, Accuracy: 0.8750
# Batch number: 009, Training: Loss: 0.2643, Accuracy: 0.9062
# Batch number: 010, Training: Loss: 0.2145, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.2022, Accuracy: 0.8750
# Batch number: 012, Training: Loss: 0.2574, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.2160, Accuracy: 0.8750
# Batch number: 014, Training: Loss: 0.2311, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.2016, Accuracy: 0.9375
# Batch number: 016, Training: Loss: 0.2720, Accuracy: 0.9375
# Batch number: 017, Training: Loss: 0.0811, Accuracy: 1.0000
# Epoch Training Loss: 0.2683
# Epoch Training Accuracy: 0.8854
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4604, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.5827, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.4178, Accuracy: 0.8571
# Epoch Validation Loss: 0.4869
# Epoch Validation Accuracy: 0.8482
# Accuracy: 0.8482142885526022 | Precision: 0.8417582417582418 | Recall: 0.8461538461538461 | F1: 0.8371794871794873 | Avg Loss: 0.48694809277852374
# Epoch: 29/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.1971, Accuracy: 0.9375
# Batch number: 001, Training: Loss: 0.1574, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.2522, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.2775, Accuracy: 0.8125
# Batch number: 004, Training: Loss: 0.4236, Accuracy: 0.8125
# Batch number: 005, Training: Loss: 0.0756, Accuracy: 1.0000
# Batch number: 006, Training: Loss: 0.1832, Accuracy: 0.9062
# Batch number: 007, Training: Loss: 0.1272, Accuracy: 0.9375
# Batch number: 008, Training: Loss: 0.1214, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.2800, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.3463, Accuracy: 0.8438
# Batch number: 011, Training: Loss: 0.1541, Accuracy: 0.9688
# Batch number: 012, Training: Loss: 0.2099, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.2002, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.1254, Accuracy: 0.9688
# Batch number: 015, Training: Loss: 0.1895, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.2174, Accuracy: 0.9688
# Batch number: 017, Training: Loss: 0.0869, Accuracy: 1.0000
# Epoch Training Loss: 0.2014
# Epoch Training Accuracy: 0.9184
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5148, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.5507, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.3586, Accuracy: 0.8571
# Epoch Validation Loss: 0.4747
# Epoch Validation Accuracy: 0.8482
# Accuracy: 0.8482142885526022 | Precision: 0.8417582417582418 | Recall: 0.8461538461538461 | F1: 0.8371794871794873 | Avg Loss: 0.47472859422365826
# Epoch: 30/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.3695, Accuracy: 0.8125
# Batch number: 001, Training: Loss: 0.3049, Accuracy: 0.8438
# Batch number: 002, Training: Loss: 0.2717, Accuracy: 0.9375
# Batch number: 003, Training: Loss: 0.0980, Accuracy: 1.0000
# Batch number: 004, Training: Loss: 0.1584, Accuracy: 0.9688
# Batch number: 005, Training: Loss: 0.2175, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.1233, Accuracy: 0.9688
# Batch number: 007, Training: Loss: 0.1983, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.2254, Accuracy: 0.9062
# Batch number: 009, Training: Loss: 0.2589, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.3522, Accuracy: 0.8438
# Batch number: 011, Training: Loss: 0.0836, Accuracy: 0.9688
# Batch number: 012, Training: Loss: 0.2866, Accuracy: 0.8750
# Batch number: 013, Training: Loss: 0.0812, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.1154, Accuracy: 0.9688
# Batch number: 015, Training: Loss: 0.2362, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.1116, Accuracy: 0.9688
# Batch number: 017, Training: Loss: 0.5187, Accuracy: 0.5000
# Epoch Training Loss: 0.2229
# Epoch Training Accuracy: 0.8958
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5549, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.5445, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.3500, Accuracy: 0.8571
# Epoch Validation Loss: 0.4831
# Epoch Validation Accuracy: 0.8378
# Accuracy: 0.8377976218859354 | Precision: 0.828125 | Recall: 0.8333333333333334 | F1: 0.8214876033057851 | Avg Loss: 0.48314542571703595
# Epoch: 31/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.2369, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.0865, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.2976, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.3150, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.1777, Accuracy: 0.9688
# Batch number: 005, Training: Loss: 0.2935, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.1926, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.1184, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.1152, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.1861, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.1420, Accuracy: 0.9688
# Batch number: 011, Training: Loss: 0.3098, Accuracy: 0.9062
# ...
# Epoch Validation Loss: 0.5118
# Epoch Validation Accuracy: 0.8036
# Accuracy: 0.8035714228947958 | Precision: 0.7979993796526055 | Recall: 0.8076923076923077 | F1: 0.798738622268034 | Avg Loss: 0.5117593705654144
# Epoch: 41/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.4199, Accuracy: 0.8125
# Batch number: 001, Training: Loss: 0.1511, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.3124, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.0853, Accuracy: 0.9688
# Batch number: 004, Training: Loss: 0.1400, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.1658, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.3053, Accuracy: 0.9062
# Batch number: 007, Training: Loss: 0.2136, Accuracy: 0.8750
# Batch number: 008, Training: Loss: 0.0771, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.2746, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.0537, Accuracy: 1.0000
# Batch number: 011, Training: Loss: 0.1284, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.1064, Accuracy: 0.9688
# Batch number: 013, Training: Loss: 0.1293, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.2376, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.2141, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.3084, Accuracy: 0.8438
# Batch number: 017, Training: Loss: 3.6469, Accuracy: 0.0000
# Epoch Training Loss: 0.3872
# Epoch Training Accuracy: 0.8646
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5406, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.5701, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.4956, Accuracy: 0.7857
# Epoch Validation Loss: 0.5354
# Epoch Validation Accuracy: 0.7932
# Accuracy: 0.793154756228129 | Precision: 0.7822485207100592 | Recall: 0.7948717948717948 | F1: 0.7774645797789481 | Avg Loss: 0.53540900349617
# Epoch: 42/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.1989, Accuracy: 0.9375
# Batch number: 001, Training: Loss: 0.1159, Accuracy: 0.9688
# Batch number: 002, Training: Loss: 0.1225, Accuracy: 0.9688
# Batch number: 003, Training: Loss: 0.2640, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.1207, Accuracy: 0.9688
# Batch number: 005, Training: Loss: 0.1013, Accuracy: 1.0000
# Batch number: 006, Training: Loss: 0.0783, Accuracy: 1.0000
# Batch number: 007, Training: Loss: 0.1103, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.1769, Accuracy: 0.9375
# Batch number: 009, Training: Loss: 0.1981, Accuracy: 0.9062
# Batch number: 010, Training: Loss: 0.1717, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.1770, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.2088, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.1870, Accuracy: 0.9062
# Batch number: 014, Training: Loss: 0.1502, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.2953, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.1794, Accuracy: 0.9375
# Batch number: 017, Training: Loss: 0.1332, Accuracy: 1.0000
# Epoch Training Loss: 0.1661
# Epoch Training Accuracy: 0.9427
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4689, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.5105, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.3686, Accuracy: 0.7857
# Epoch Validation Loss: 0.4493
# Epoch Validation Accuracy: 0.8036
# Accuracy: 0.8035714228947958 | Precision: 0.7974759615384616 | Recall: 0.8076923076923077 | F1: 0.7940241576605213 | Avg Loss: 0.44933463136355084
# Epoch: 43/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.2122, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.1674, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.0631, Accuracy: 1.0000
# Batch number: 003, Training: Loss: 0.1926, Accuracy: 0.9688
# Batch number: 004, Training: Loss: 0.1844, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.1966, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.1536, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.1298, Accuracy: 0.9375
# Batch number: 008, Training: Loss: 0.1834, Accuracy: 0.9375
# Batch number: 009, Training: Loss: 0.1072, Accuracy: 0.9688
# Batch number: 010, Training: Loss: 0.1441, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.1936, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.1574, Accuracy: 0.9688
# Batch number: 013, Training: Loss: 0.1534, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.1816, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.1648, Accuracy: 0.9688
# Batch number: 016, Training: Loss: 0.0984, Accuracy: 1.0000
# Batch number: 017, Training: Loss: 0.0472, Accuracy: 1.0000
# Epoch Training Loss: 0.1517
# Epoch Training Accuracy: 0.9497
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4810, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.4713, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.2974, Accuracy: 0.7857
# Epoch Validation Loss: 0.4166
# Epoch Validation Accuracy: 0.8244
# Accuracy: 0.824404756228129 | Precision: 0.828125 | Recall: 0.8333333333333334 | F1: 0.8214876033057851 | Avg Loss: 0.41657992204030353
# Epoch: 44/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.1475, Accuracy: 0.9375
# Batch number: 001, Training: Loss: 0.1683, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.1630, Accuracy: 0.9375
# Batch number: 003, Training: Loss: 0.1462, Accuracy: 0.9688
# Batch number: 004, Training: Loss: 0.1296, Accuracy: 0.9062
# Batch number: 005, Training: Loss: 0.1634, Accuracy: 0.9688
# Batch number: 006, Training: Loss: 0.1480, Accuracy: 0.9062
# Batch number: 007, Training: Loss: 0.1097, Accuracy: 1.0000
# Batch number: 008, Training: Loss: 0.1003, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.1089, Accuracy: 1.0000
# Batch number: 010, Training: Loss: 0.2095, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.2344, Accuracy: 0.9375
# Batch number: 012, Training: Loss: 0.3093, Accuracy: 0.8750
# Batch number: 013, Training: Loss: 0.0887, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.1912, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.0707, Accuracy: 1.0000
# Batch number: 016, Training: Loss: 0.0505, Accuracy: 1.0000
# Batch number: 017, Training: Loss: 0.0366, Accuracy: 1.0000
# Epoch Training Loss: 0.1431
# Epoch Training Accuracy: 0.9514
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4621, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.4972, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.3106, Accuracy: 0.8571
# Epoch Validation Loss: 0.4233
# Epoch Validation Accuracy: 0.8482
# Accuracy: 0.8482142885526022 | Precision: 0.8417582417582418 | Recall: 0.8461538461538461 | F1: 0.8371794871794873 | Avg Loss: 0.423317809899648
# Epoch: 45/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.1987, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.1489, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.0841, Accuracy: 0.9688
# Batch number: 003, Training: Loss: 0.0914, Accuracy: 0.9688
# Batch number: 004, Training: Loss: 0.0960, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.0651, Accuracy: 1.0000
# Batch number: 006, Training: Loss: 0.3049, Accuracy: 0.8750
# Batch number: 007, Training: Loss: 0.0596, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.1426, Accuracy: 0.9375
# Batch number: 009, Training: Loss: 0.1665, Accuracy: 0.9375
# Batch number: 010, Training: Loss: 0.1894, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.0466, Accuracy: 1.0000
# Batch number: 012, Training: Loss: 0.0460, Accuracy: 1.0000
# Batch number: 013, Training: Loss: 0.1037, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.0798, Accuracy: 0.9688
# Batch number: 015, Training: Loss: 0.2572, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.2051, Accuracy: 0.9688
# Batch number: 017, Training: Loss: 0.0195, Accuracy: 1.0000
# Epoch Training Loss: 0.1281
# Epoch Training Accuracy: 0.9514
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4604, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.5118, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.3074, Accuracy: 0.8571
# Epoch Validation Loss: 0.4265
# Epoch Validation Accuracy: 0.8482
# Accuracy: 0.8482142885526022 | Precision: 0.8417582417582418 | Recall: 0.8461538461538461 | F1: 0.8371794871794873 | Avg Loss: 0.4265398581822713
# Epoch: 46/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.2047, Accuracy: 0.9375
# Batch number: 001, Training: Loss: 0.1023, Accuracy: 0.9688
# Batch number: 002, Training: Loss: 0.1104, Accuracy: 0.9688
# Batch number: 003, Training: Loss: 0.1778, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.0983, Accuracy: 0.9688
# Batch number: 005, Training: Loss: 0.1110, Accuracy: 0.9688
# Batch number: 006, Training: Loss: 0.1311, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.0957, Accuracy: 1.0000
# Batch number: 008, Training: Loss: 0.0898, Accuracy: 1.0000
# Batch number: 009, Training: Loss: 0.1183, Accuracy: 0.9688
# Batch number: 010, Training: Loss: 0.1645, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.2445, Accuracy: 0.8750
# Batch number: 012, Training: Loss: 0.0622, Accuracy: 0.9688
# Batch number: 013, Training: Loss: 0.1096, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.1323, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.1547, Accuracy: 0.9375
# Batch number: 016, Training: Loss: 0.2784, Accuracy: 0.8750
# Batch number: 017, Training: Loss: 0.2349, Accuracy: 1.0000
# Epoch Training Loss: 0.1456
# Epoch Training Accuracy: 0.9497
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4624, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.4950, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.3334, Accuracy: 0.8571
# Epoch Validation Loss: 0.4303
# Epoch Validation Accuracy: 0.8482
# Accuracy: 0.8482142885526022 | Precision: 0.8417582417582418 | Recall: 0.8461538461538461 | F1: 0.8371794871794873 | Avg Loss: 0.43025272091229755
# Epoch: 47/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.1302, Accuracy: 0.9375
# Batch number: 001, Training: Loss: 0.0321, Accuracy: 1.0000
# Batch number: 002, Training: Loss: 0.1643, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.2261, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.1364, Accuracy: 0.9688
# Batch number: 005, Training: Loss: 0.0281, Accuracy: 1.0000
# Batch number: 006, Training: Loss: 0.0813, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.1585, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.1156, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.0876, Accuracy: 0.9688
# Batch number: 010, Training: Loss: 0.2185, Accuracy: 0.8438
# Batch number: 011, Training: Loss: 0.1270, Accuracy: 0.9688
# Batch number: 012, Training: Loss: 0.0531, Accuracy: 0.9688
# Batch number: 013, Training: Loss: 0.0945, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.2056, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.1325, Accuracy: 0.9375
# Batch number: 016, Training: Loss: 0.1399, Accuracy: 0.9688
# Batch number: 017, Training: Loss: 0.0345, Accuracy: 1.0000
# Epoch Training Loss: 0.1203
# Epoch Training Accuracy: 0.9462
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3913, Accuracy: 0.8750
# Batch number: 001, Validation: Loss: 0.4348, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.4624, Accuracy: 0.8571
# Epoch Validation Loss: 0.4295
# Epoch Validation Accuracy: 0.8586
# Accuracy: 0.8586309552192688 | Precision: 0.8552264267990076 | Recall: 0.8589743589743589 | F1: 0.8524083229965583 | Avg Loss: 0.42949699362119037
# Epoch: 48/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.2272, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.1124, Accuracy: 0.9688
# Batch number: 002, Training: Loss: 0.1182, Accuracy: 0.9375
# Batch number: 003, Training: Loss: 0.2184, Accuracy: 0.9062
# Batch number: 004, Training: Loss: 0.4382, Accuracy: 0.8438
# Batch number: 005, Training: Loss: 0.0502, Accuracy: 1.0000
# Batch number: 006, Training: Loss: 0.1967, Accuracy: 0.8750
# Batch number: 007, Training: Loss: 0.0585, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.1200, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.0826, Accuracy: 0.9688
# Batch number: 010, Training: Loss: 0.1843, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.2587, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.0252, Accuracy: 1.0000
# Batch number: 013, Training: Loss: 0.0413, Accuracy: 1.0000
# Batch number: 014, Training: Loss: 0.1172, Accuracy: 0.9688
# Batch number: 015, Training: Loss: 0.1036, Accuracy: 0.9375
# Batch number: 016, Training: Loss: 0.0947, Accuracy: 0.9688
# Batch number: 017, Training: Loss: 2.0095, Accuracy: 0.5000
# Epoch Training Loss: 0.2476
# Epoch Training Accuracy: 0.9201
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4314, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.4406, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.5230, Accuracy: 0.8571
# Epoch Validation Loss: 0.4650
# Epoch Validation Accuracy: 0.8586
# Accuracy: 0.8586309552192688 | Precision: 0.8587740384615384 | Recall: 0.8589743589743589 | F1: 0.848951048951049 | Avg Loss: 0.4649905761082967
# Epoch: 49/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.1140, Accuracy: 0.9688
# Batch number: 001, Training: Loss: 0.1036, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.1843, Accuracy: 0.9062
# Batch number: 003, Training: Loss: 0.1242, Accuracy: 0.9375
# Batch number: 004, Training: Loss: 0.1595, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.2052, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.1877, Accuracy: 0.9062
# Batch number: 007, Training: Loss: 0.1027, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.0885, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.2088, Accuracy: 0.9375
# Batch number: 010, Training: Loss: 0.1323, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.1210, Accuracy: 0.9688
# Batch number: 012, Training: Loss: 0.1891, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.1609, Accuracy: 0.9062
# Batch number: 014, Training: Loss: 0.1244, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.1177, Accuracy: 0.9688
# Batch number: 016, Training: Loss: 0.0406, Accuracy: 1.0000
# Batch number: 017, Training: Loss: 0.0921, Accuracy: 1.0000
# Epoch Training Loss: 0.1365
# Epoch Training Accuracy: 0.9427
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4601, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.3773, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.4323, Accuracy: 0.8571
# Epoch Validation Loss: 0.4232
# Epoch Validation Accuracy: 0.8586
# Accuracy: 0.8586309552192688 | Precision: 0.8587740384615384 | Recall: 0.8589743589743589 | F1: 0.848951048951049 | Avg Loss: 0.42320366700490314
# Epoch: 50/50
#
# [Training]
# Batch number: 000, Training: Loss: 0.0490, Accuracy: 1.0000
# Batch number: 001, Training: Loss: 0.2317, Accuracy: 0.8750
# Batch number: 002, Training: Loss: 0.0468, Accuracy: 1.0000
# Batch number: 003, Training: Loss: 0.1367, Accuracy: 0.9375
# Batch number: 004, Training: Loss: 0.1944, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.2788, Accuracy: 0.8750
# Batch number: 006, Training: Loss: 0.1738, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.1161, Accuracy: 0.9375
# Batch number: 008, Training: Loss: 0.0553, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.1986, Accuracy: 0.9375
# Batch number: 010, Training: Loss: 0.1841, Accuracy: 0.9375
# Batch number: 011, Training: Loss: 0.0429, Accuracy: 1.0000
# Batch number: 012, Training: Loss: 0.0433, Accuracy: 1.0000
# Batch number: 013, Training: Loss: 0.0621, Accuracy: 1.0000
# Batch number: 014, Training: Loss: 0.1673, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.3080, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.0905, Accuracy: 0.9688
# Batch number: 017, Training: Loss: 2.1167, Accuracy: 0.5000
# Epoch Training Loss: 0.2498
# Epoch Training Accuracy: 0.9236
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4973, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.4225, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.4038, Accuracy: 0.8571
# Epoch Validation Loss: 0.4412
# Epoch Validation Accuracy: 0.8586
# Accuracy: 0.8586309552192688 | Precision: 0.8587740384615384 | Recall: 0.8589743589743589 | F1: 0.848951048951049 | Avg Loss: 0.44117048382759094

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), train_losses, label="Training Loss", marker='o')
plt.plot(range(1, epochs + 1), val_losses, label="Validation Loss", marker='x')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), val_accuracies, label="Validation Accuracy", marker='s', color='g')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), train_losses, label="Training Loss", marker='o')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import precision_recall_fscore_support

test_loss = 0.0
correct = 0.0
preds = []
labels_ = []

with torch.no_grad():
    model.eval()
    for i, (inputs, labels) in enumerate(dataloader_test):
        inputs = inputs.squeeze(1).to(device)
        inputs = inputs.repeat(1, 3, 1, 1) # For models that need 3 channels
        labels = labels.to(device).type(torch.float)

        outputs = model(inputs)
        preds.extend(outputs.round().cpu().numpy())
        labels_.extend(labels.round().cpu().numpy())

        loss = criterion(outputs, labels)
        test_loss += loss.item() * inputs.size(0)
        correct += (outputs.round() == labels).float().sum().item()

acc = correct / len(dataloader_test.dataset)
avg_loss = test_loss / len(dataloader_test.dataset)
precision, recall, fscore, _ = precision_recall_fscore_support(labels_, preds, average="weighted", zero_division=np.nan)
print(f"Accuracy: {acc} | Precision: {precision} | Recall: {recall} | F1: {fscore} | Avg Loss: {avg_loss}")
# Out:
# Accuracy: 0.8333333333333334 | Precision: 0.8291703835860839 | Recall: 0.8333333333333334 | F1: 0.8306034482758622 | Avg Loss: 0.5109947125116984

# %%
conf_matrix = confusion_matrix(labels_, preds)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negativo', 'Positivo'], yticklabels=['Negativo', 'Positivo'])
plt.xlabel('Predito')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()
