# %%
import os

import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torch.utils.data as data
import torchvision.transforms as transforms
from torchvision.models import resnet18, ResNet18_Weights
import torch.nn.functional as F
from pydicom import Dataset

from tqdm import tqdm

from medmnist import BreastMNIST
from medmnist import INFO

import pennylane as qml

import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print(f"Using: {torch.cuda.get_device_name(0)}")
    print(f"CUDA: {torch.version.cuda}")
else:
    print("CUDA is not available. Using CPU.")
# Out:
# Using: NVIDIA GeForce RTX 3050 6GB Laptop GPU
# CUDA: 11.8

# %%
info = INFO['breastmnist']
data_flag = 'breastmnist'
DataClass = BreastMNIST

task = info['task']  
n_channels = info['n_channels']
n_classes = len(info['label'])

print(f"Number of classes:", n_classes)
print(f"Number of channels: {n_channels}")

train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),  
    transforms.RandomRotation(degrees=15),  
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5]),
    lambda x: x.unsqueeze(0)
])

eval_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5]),
    lambda x: x.unsqueeze(0)
])
# Out:
# Number of classes: 2
# Number of channels: 1

# %%
# data_train28 = DataClass(split='train', transform=train_transform, download=True)
# data_test28 = DataClass(split='test', transform=eval_transform, download=True)
# data_eval28 = DataClass(split='val', transform=eval_transform, download=True)

data_train64 = DataClass(split='train', transform=train_transform, download=True, size=64)
data_test64 = DataClass(split='test', transform=eval_transform, download=True, size=64)
data_eval64 = DataClass(split='val', transform=eval_transform, download=True, size=64)
# Out:
# Using downloaded and verified file: C:\Users\enzog\.medmnist\breastmnist_64.npz
# Using downloaded and verified file: C:\Users\enzog\.medmnist\breastmnist_64.npz
# Using downloaded and verified file: C:\Users\enzog\.medmnist\breastmnist_64.npz

# %%
batch_size = 32 

# dataloader_train = data.DataLoader(dataset=data_train28, batch_size=batch_size, shuffle=True)
# dataloader_test = data.DataLoader(dataset=data_test28, batch_size=batch_size, shuffle=False)
# dataloader_eval = data.DataLoader(dataset=data_eval28, batch_size=batch_size, shuffle=False)

# print(f"\nNumber of images in training dataset: {len(data_train28)}")
# print(f"Number of images in test dataset: {len(data_test28)}")
# print(f"Number of images in validation dataset: {len(data_eval28)}")

dataloader_train = data.DataLoader(dataset=data_train64, batch_size=batch_size, shuffle=True)
dataloader_test = data.DataLoader(dataset=data_test64, batch_size=batch_size, shuffle=False)
dataloader_eval = data.DataLoader(dataset=data_eval64, batch_size=batch_size, shuffle=False)

print(f"\nNumber of images in training dataset: {len(data_train64)}")
print(f"Number of images in test dataset: {len(data_test64)}")
print(f"Number of images in validation dataset: {len(data_eval64)}")
# Out:
# Number of images in training dataset: 546
# Number of images in test dataset: 156
# Number of images in validation dataset: 78

# %%
from torchvision.models import resnet18, ResNet18_Weights

model = resnet18(weights=ResNet18_Weights.DEFAULT)

# Freeze model parameters
for param in model.parameters():
    param.requires_grad = True

# Change the final layer of VGG16 Model for Transfer Learning
model.fc = nn.Sequential(
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 128),
    nn.ReLU(),
    nn.Linear(128, 1),
    #nn.ReLU(),
    #nn.Dropout(0.4),
    #nn.Linear(64, 1),
    nn.Sigmoid()
)
print(model)
model = model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
criterion = nn.BCELoss().to(device)
epochs = 10
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=512, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=256, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Linear(in_features=128, out_features=1, bias=True)
#     (6): Sigmoid()
#   )
# )

# %%
from sklearn.metrics import precision_recall_fscore_support

train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
val_precisions = []
val_recalls = []
val_f1_scores = []
val_aucs = []

for epoch in range(epochs):
        print("Epoch: {}/{}".format(epoch+1, epochs))
        # Set to training mode
        model.train()
        # Loss and Accuracy within the epoch
        total_loss = 0.0
        total_acc = 0.0
        print("\n[Training]")
        for i, (inputs, labels) in enumerate(dataloader_train):
            inputs = inputs.squeeze(1).to(device)
            inputs = inputs.repeat(1, 3, 1, 1) # For models that need 3 channels
            labels = labels.to(device).type(torch.float)     
            # Clean existing gradients
            optimizer.zero_grad()
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            # print(f"Labels shape: {labels.shape}")
            # print(f"Outputs shape: {outputs.shape}")
            # Compute loss
            loss = criterion(outputs, labels)
            # Backpropagate the gradients
            loss.backward()
            # Update the parameters
            optimizer.step()
            # Compute the total loss for the batch and add it to train_loss
            total_loss += loss.item()
            # Compute the accuracy
            predictions = outputs.round()
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            # Compute total accuracy in the whole batch and add to train_acc
            total_acc += acc.item()
            print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

        epoch_train_loss = total_loss / len(dataloader_train)
        train_losses.append(epoch_train_loss)
        print(f"Epoch Training Loss: {epoch_train_loss:.4f}")

        epoch_train_acc = total_acc / len(dataloader_train)
        train_accuracies.append(epoch_train_acc)
        print(f"Epoch Training Accuracy: {epoch_train_acc:.4f}")

        model.eval()
        val_loss = 0.0
        val_acc = 0.0
        val_labels, val_predictions = [], []
        print("\n[Validation]")
        with torch.no_grad():
            for i, (inputs, labels) in enumerate(dataloader_eval):
                inputs = inputs.squeeze(1).to(device)
                inputs = inputs.repeat(1, 3, 1, 1) # For models that need 3 channels
                labels = labels.to(device).type(torch.float)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                val_labels.extend(labels.round().cpu().numpy())
                val_predictions.extend(outputs.round().cpu().numpy())
                # Compute the accuracy
                predictions = outputs.round()
                correct_counts = predictions.eq(labels.data.view_as(predictions))
                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))
                # Compute total accuracy in the whole batch and add to train_acc
                val_acc += acc.item()
                print("Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

        epoch_val_loss = val_loss / len(dataloader_eval)
        val_losses.append(epoch_val_loss)
        print(f"Epoch Validation Loss: {epoch_val_loss:.4f}")

        epoch_val_acc = val_acc / len(dataloader_eval)
        val_accuracies.append(epoch_val_acc)
        print(f"Epoch Validation Accuracy: {epoch_val_acc:.4f}")

        precision, recall, fscore, _ = precision_recall_fscore_support(val_labels, val_predictions, average="weighted", zero_division=np.nan)
        print(f"Accuracy: {epoch_val_acc} | Precision: {precision} | Recall: {recall} | F1: {fscore} | Avg Loss: {epoch_val_loss}")
# Out:
# Epoch: 1/10
#
# [Training]
# Batch number: 000, Training: Loss: 0.6784, Accuracy: 0.5625
# Batch number: 001, Training: Loss: 0.6478, Accuracy: 0.7812
# Batch number: 002, Training: Loss: 0.6817, Accuracy: 0.5938
# Batch number: 003, Training: Loss: 0.6366, Accuracy: 0.7500
# Batch number: 004, Training: Loss: 0.6313, Accuracy: 0.7500
# Batch number: 005, Training: Loss: 0.6838, Accuracy: 0.6250
# Batch number: 006, Training: Loss: 0.5854, Accuracy: 0.7500
# Batch number: 007, Training: Loss: 0.5845, Accuracy: 0.7812
# Batch number: 008, Training: Loss: 0.5911, Accuracy: 0.7188
# Batch number: 009, Training: Loss: 0.6116, Accuracy: 0.6875
# Batch number: 010, Training: Loss: 0.5310, Accuracy: 0.7812
# Batch number: 011, Training: Loss: 0.5529, Accuracy: 0.7188
# Batch number: 012, Training: Loss: 0.4398, Accuracy: 0.9375
# Batch number: 013, Training: Loss: 0.6756, Accuracy: 0.5938
# Batch number: 014, Training: Loss: 0.4986, Accuracy: 0.7812
# Batch number: 015, Training: Loss: 0.4998, Accuracy: 0.7812
# Batch number: 016, Training: Loss: 0.5389, Accuracy: 0.6875
# Batch number: 017, Training: Loss: 0.3246, Accuracy: 1.0000
# Epoch Training Loss: 0.5774
# Epoch Training Accuracy: 0.7378
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5824, Accuracy: 0.7188
# Batch number: 001, Validation: Loss: 0.5180, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.4956, Accuracy: 0.6429
# Epoch Validation Loss: 0.5320
# Epoch Validation Accuracy: 0.7143
# Accuracy: 0.7142857114473978 | Precision: 0.7307692307692307 | Recall: 0.7307692307692307 | F1: 0.6170940170940171 | Avg Loss: 0.5320284068584442
# Epoch: 2/10
#
# [Training]
# Batch number: 000, Training: Loss: 0.5899, Accuracy: 0.6562
# Batch number: 001, Training: Loss: 0.4695, Accuracy: 0.8438
# Batch number: 002, Training: Loss: 0.5905, Accuracy: 0.5625
# Batch number: 003, Training: Loss: 0.3874, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.3900, Accuracy: 0.8125
# Batch number: 005, Training: Loss: 0.5084, Accuracy: 0.7500
# Batch number: 006, Training: Loss: 0.4179, Accuracy: 0.7500
# Batch number: 007, Training: Loss: 0.4740, Accuracy: 0.7500
# Batch number: 008, Training: Loss: 0.3974, Accuracy: 0.7500
# Batch number: 009, Training: Loss: 0.5985, Accuracy: 0.6562
# Batch number: 010, Training: Loss: 0.4742, Accuracy: 0.6875
# Batch number: 011, Training: Loss: 0.3330, Accuracy: 0.8750
# Batch number: 012, Training: Loss: 0.4769, Accuracy: 0.6562
# Batch number: 013, Training: Loss: 0.4369, Accuracy: 0.8125
# Batch number: 014, Training: Loss: 0.6723, Accuracy: 0.5938
# Batch number: 015, Training: Loss: 0.3367, Accuracy: 0.7812
# Batch number: 016, Training: Loss: 0.6321, Accuracy: 0.5938
# Batch number: 017, Training: Loss: 0.1944, Accuracy: 1.0000
# Epoch Training Loss: 0.4655
# Epoch Training Accuracy: 0.7448
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4492, Accuracy: 0.7188
# Batch number: 001, Validation: Loss: 0.4485, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.4017, Accuracy: 0.6429
# Epoch Validation Loss: 0.4331
# Epoch Validation Accuracy: 0.7143
# Accuracy: 0.7142857114473978 | Precision: 0.7307692307692307 | Recall: 0.7307692307692307 | F1: 0.6170940170940171 | Avg Loss: 0.43313069144884747
# Epoch: 3/10
#
# [Training]
# Batch number: 000, Training: Loss: 0.3924, Accuracy: 0.7188
# Batch number: 001, Training: Loss: 0.4306, Accuracy: 0.7188
# Batch number: 002, Training: Loss: 0.3357, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.4578, Accuracy: 0.6562
# Batch number: 004, Training: Loss: 0.3705, Accuracy: 0.8125
# Batch number: 005, Training: Loss: 0.4818, Accuracy: 0.6875
# Batch number: 006, Training: Loss: 0.4790, Accuracy: 0.7188
# Batch number: 007, Training: Loss: 0.3588, Accuracy: 0.8125
# Batch number: 008, Training: Loss: 0.3958, Accuracy: 0.7188
# Batch number: 009, Training: Loss: 0.4375, Accuracy: 0.7188
# Batch number: 010, Training: Loss: 0.3142, Accuracy: 0.8125
# Batch number: 011, Training: Loss: 0.4305, Accuracy: 0.6562
# Batch number: 012, Training: Loss: 0.5654, Accuracy: 0.5625
# Batch number: 013, Training: Loss: 0.3598, Accuracy: 0.8750
# Batch number: 014, Training: Loss: 0.3829, Accuracy: 0.7500
# Batch number: 015, Training: Loss: 0.3584, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.4009, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 0.3740, Accuracy: 0.5000
# Epoch Training Loss: 0.4070
# Epoch Training Accuracy: 0.7361
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.4200, Accuracy: 0.7500
# Batch number: 001, Validation: Loss: 0.3978, Accuracy: 0.7812
# Batch number: 002, Validation: Loss: 0.3545, Accuracy: 0.7143
# Epoch Validation Loss: 0.3908
# Epoch Validation Accuracy: 0.7485
# Accuracy: 0.7485119104385376 | Precision: 0.8173076923076923 | Recall: 0.7564102564102564 | F1: 0.6731963688485427 | Avg Loss: 0.3907662530740102
# Epoch: 4/10
#
# [Training]
# Batch number: 000, Training: Loss: 0.3095, Accuracy: 0.8750
# Batch number: 001, Training: Loss: 0.2663, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.4249, Accuracy: 0.7500
# Batch number: 003, Training: Loss: 0.3961, Accuracy: 0.8125
# Batch number: 004, Training: Loss: 0.3319, Accuracy: 0.8438
# Batch number: 005, Training: Loss: 0.3197, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.3426, Accuracy: 0.8750
# Batch number: 007, Training: Loss: 0.3395, Accuracy: 0.8438
# Batch number: 008, Training: Loss: 0.2595, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.4379, Accuracy: 0.7812
# Batch number: 010, Training: Loss: 0.2923, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.5504, Accuracy: 0.7812
# Batch number: 012, Training: Loss: 0.6377, Accuracy: 0.7188
# Batch number: 013, Training: Loss: 0.5396, Accuracy: 0.8750
# Batch number: 014, Training: Loss: 0.3936, Accuracy: 0.8438
# Batch number: 015, Training: Loss: 0.3922, Accuracy: 0.8438
# Batch number: 016, Training: Loss: 0.3350, Accuracy: 0.9062
# Batch number: 017, Training: Loss: 0.1412, Accuracy: 1.0000
# Epoch Training Loss: 0.3728
# Epoch Training Accuracy: 0.8559
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3573, Accuracy: 0.8125
# Batch number: 001, Validation: Loss: 0.3610, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.2972, Accuracy: 0.9286
# Epoch Validation Loss: 0.3385
# Epoch Validation Accuracy: 0.8616
# Accuracy: 0.8616071343421936 | Precision: 0.8555474376369898 | Recall: 0.8461538461538461 | F1: 0.828318858560794 | Avg Loss: 0.3385152320067088
# Epoch: 5/10
#
# [Training]
# Batch number: 000, Training: Loss: 0.3672, Accuracy: 0.8125
# Batch number: 001, Training: Loss: 0.3467, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.3705, Accuracy: 0.7500
# Batch number: 003, Training: Loss: 0.2521, Accuracy: 0.9375
# Batch number: 004, Training: Loss: 0.4030, Accuracy: 0.7500
# Batch number: 005, Training: Loss: 0.3898, Accuracy: 0.9062
# Batch number: 006, Training: Loss: 0.3002, Accuracy: 0.8438
# Batch number: 007, Training: Loss: 0.2614, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.4188, Accuracy: 0.7812
# Batch number: 009, Training: Loss: 0.3435, Accuracy: 0.9062
# Batch number: 010, Training: Loss: 0.3425, Accuracy: 0.8438
# Batch number: 011, Training: Loss: 0.2332, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.3521, Accuracy: 0.9062
# Batch number: 013, Training: Loss: 0.2537, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.2858, Accuracy: 0.9062
# Batch number: 015, Training: Loss: 0.2926, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.3478, Accuracy: 0.8438
# Batch number: 017, Training: Loss: 0.1006, Accuracy: 1.0000
# Epoch Training Loss: 0.3145
# Epoch Training Accuracy: 0.8802
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3633, Accuracy: 0.7812
# Batch number: 001, Validation: Loss: 0.3285, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.2427, Accuracy: 0.9286
# Epoch Validation Loss: 0.3115
# Epoch Validation Accuracy: 0.8720
# Accuracy: 0.8720238010088602 | Precision: 0.8817873303167421 | Recall: 0.8589743589743589 | F1: 0.8401588089330025 | Avg Loss: 0.31146592895189923
# Epoch: 6/10
#
# [Training]
# Batch number: 000, Training: Loss: 0.3142, Accuracy: 0.9062
# Batch number: 001, Training: Loss: 0.3031, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.2261, Accuracy: 1.0000
# Batch number: 003, Training: Loss: 0.3113, Accuracy: 0.8125
# Batch number: 004, Training: Loss: 0.3780, Accuracy: 0.7812
# Batch number: 005, Training: Loss: 0.1987, Accuracy: 0.9688
# Batch number: 006, Training: Loss: 0.2310, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.2697, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.3943, Accuracy: 0.8438
# Batch number: 009, Training: Loss: 0.1820, Accuracy: 1.0000
# Batch number: 010, Training: Loss: 0.3173, Accuracy: 0.8750
# Batch number: 011, Training: Loss: 0.2326, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.2276, Accuracy: 0.9375
# Batch number: 013, Training: Loss: 0.2848, Accuracy: 0.8750
# Batch number: 014, Training: Loss: 0.3418, Accuracy: 0.8125
# Batch number: 015, Training: Loss: 0.2638, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.4289, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 0.3206, Accuracy: 1.0000
# Epoch Training Loss: 0.2903
# Epoch Training Accuracy: 0.9010
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3314, Accuracy: 0.8438
# Batch number: 001, Validation: Loss: 0.3849, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.2628, Accuracy: 0.9286
# Epoch Validation Loss: 0.3264
# Epoch Validation Accuracy: 0.8720
# Accuracy: 0.8720238010088602 | Precision: 0.866841491841492 | Recall: 0.8589743589743589 | F1: 0.8449030644152595 | Avg Loss: 0.32638002435366315
# Epoch: 7/10
#
# [Training]
# Batch number: 000, Training: Loss: 0.2603, Accuracy: 0.9688
# Batch number: 001, Training: Loss: 0.2279, Accuracy: 0.9062
# Batch number: 002, Training: Loss: 0.2602, Accuracy: 0.8750
# Batch number: 003, Training: Loss: 0.1997, Accuracy: 0.9375
# Batch number: 004, Training: Loss: 0.3135, Accuracy: 0.9062
# Batch number: 005, Training: Loss: 0.1779, Accuracy: 1.0000
# Batch number: 006, Training: Loss: 0.2445, Accuracy: 0.9688
# Batch number: 007, Training: Loss: 0.2041, Accuracy: 0.9688
# Batch number: 008, Training: Loss: 0.1420, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.2780, Accuracy: 0.8438
# Batch number: 010, Training: Loss: 0.1659, Accuracy: 0.9688
# Batch number: 011, Training: Loss: 0.2910, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.2858, Accuracy: 0.8438
# Batch number: 013, Training: Loss: 0.1623, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.1637, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.3448, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.1428, Accuracy: 1.0000
# Batch number: 017, Training: Loss: 0.4829, Accuracy: 0.5000
# Epoch Training Loss: 0.2415
# Epoch Training Accuracy: 0.9097
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.3229, Accuracy: 0.9062
# Batch number: 001, Validation: Loss: 0.2761, Accuracy: 0.9062
# Batch number: 002, Validation: Loss: 0.1358, Accuracy: 1.0000
# Epoch Validation Loss: 0.2449
# Epoch Validation Accuracy: 0.9375
# Accuracy: 0.9375 | Precision: 0.9242637786514354 | Recall: 0.9230769230769231 | F1: 0.9203321210457696 | Avg Loss: 0.2449121574560801
# Epoch: 8/10
#
# [Training]
# Batch number: 000, Training: Loss: 0.2937, Accuracy: 0.8750
# Batch number: 001, Training: Loss: 0.1384, Accuracy: 0.9688
# Batch number: 002, Training: Loss: 0.1858, Accuracy: 0.9375
# Batch number: 003, Training: Loss: 0.1479, Accuracy: 0.9688
# Batch number: 004, Training: Loss: 0.5386, Accuracy: 0.8125
# Batch number: 005, Training: Loss: 0.1502, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.1220, Accuracy: 1.0000
# Batch number: 007, Training: Loss: 0.1998, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.1695, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.2947, Accuracy: 0.9062
# Batch number: 010, Training: Loss: 0.2610, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.2697, Accuracy: 0.8750
# Batch number: 012, Training: Loss: 0.1980, Accuracy: 0.9375
# Batch number: 013, Training: Loss: 0.1367, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.2064, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.2112, Accuracy: 0.8750
# Batch number: 016, Training: Loss: 0.3045, Accuracy: 0.8125
# Batch number: 017, Training: Loss: 0.1300, Accuracy: 1.0000
# Epoch Training Loss: 0.2199
# Epoch Training Accuracy: 0.9219
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.2167, Accuracy: 0.9375
# Batch number: 001, Validation: Loss: 0.3205, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.1120, Accuracy: 1.0000
# Epoch Validation Loss: 0.2164
# Epoch Validation Accuracy: 0.9375
# Accuracy: 0.9375 | Precision: 0.9230769230769231 | Recall: 0.9230769230769231 | F1: 0.9230769230769231 | Avg Loss: 0.21640127897262573
# Epoch: 9/10
#
# [Training]
# Batch number: 000, Training: Loss: 0.1933, Accuracy: 0.9375
# Batch number: 001, Training: Loss: 0.1936, Accuracy: 0.9375
# Batch number: 002, Training: Loss: 0.1264, Accuracy: 0.9688
# Batch number: 003, Training: Loss: 0.1603, Accuracy: 0.9375
# Batch number: 004, Training: Loss: 0.2134, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.0958, Accuracy: 1.0000
# Batch number: 006, Training: Loss: 0.2038, Accuracy: 0.9062
# Batch number: 007, Training: Loss: 0.1869, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.1721, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.4281, Accuracy: 0.8750
# Batch number: 010, Training: Loss: 0.2146, Accuracy: 0.9062
# Batch number: 011, Training: Loss: 0.2270, Accuracy: 0.9062
# Batch number: 012, Training: Loss: 0.2056, Accuracy: 0.8750
# Batch number: 013, Training: Loss: 0.1381, Accuracy: 0.9375
# Batch number: 014, Training: Loss: 0.5252, Accuracy: 0.9375
# Batch number: 015, Training: Loss: 0.1676, Accuracy: 0.9062
# Batch number: 016, Training: Loss: 0.2363, Accuracy: 0.9375
# Batch number: 017, Training: Loss: 0.0212, Accuracy: 1.0000
# Epoch Training Loss: 0.2061
# Epoch Training Accuracy: 0.9323
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.5326, Accuracy: 0.8750
# Batch number: 001, Validation: Loss: 0.3754, Accuracy: 0.8750
# Batch number: 002, Validation: Loss: 0.1342, Accuracy: 0.9286
# Epoch Validation Loss: 0.3474
# Epoch Validation Accuracy: 0.8929
# Accuracy: 0.8928571343421936 | Precision: 0.8894230769230769 | Recall: 0.8846153846153846 | F1: 0.8764144945963127 | Avg Loss: 0.34741932650407154
# Epoch: 10/10
#
# [Training]
# Batch number: 000, Training: Loss: 0.0847, Accuracy: 0.9688
# Batch number: 001, Training: Loss: 0.1091, Accuracy: 1.0000
# Batch number: 002, Training: Loss: 0.3065, Accuracy: 0.8438
# Batch number: 003, Training: Loss: 0.4438, Accuracy: 0.8750
# Batch number: 004, Training: Loss: 0.1172, Accuracy: 0.9375
# Batch number: 005, Training: Loss: 0.1543, Accuracy: 0.9375
# Batch number: 006, Training: Loss: 0.1680, Accuracy: 0.9375
# Batch number: 007, Training: Loss: 0.2288, Accuracy: 0.9062
# Batch number: 008, Training: Loss: 0.0915, Accuracy: 0.9688
# Batch number: 009, Training: Loss: 0.0753, Accuracy: 0.9688
# Batch number: 010, Training: Loss: 0.2156, Accuracy: 0.9688
# Batch number: 011, Training: Loss: 0.1387, Accuracy: 0.9688
# Batch number: 012, Training: Loss: 0.2238, Accuracy: 0.9688
# Batch number: 013, Training: Loss: 0.1272, Accuracy: 0.9688
# Batch number: 014, Training: Loss: 0.5443, Accuracy: 0.8438
# Batch number: 015, Training: Loss: 0.1949, Accuracy: 0.9375
# Batch number: 016, Training: Loss: 0.2480, Accuracy: 0.8750
# Batch number: 017, Training: Loss: 0.0547, Accuracy: 1.0000
# Epoch Training Loss: 0.1959
# Epoch Training Accuracy: 0.9375
#
# [Validation]
# Batch number: 000, Validation: Loss: 0.2201, Accuracy: 0.8750
# Batch number: 001, Validation: Loss: 0.3880, Accuracy: 0.8438
# Batch number: 002, Validation: Loss: 0.0700, Accuracy: 1.0000
# Epoch Validation Loss: 0.2260
# Epoch Validation Accuracy: 0.9062
# Accuracy: 0.90625 | Precision: 0.8831564986737401 | Recall: 0.8846153846153846 | F1: 0.8837099274002773 | Avg Loss: 0.22602413594722748

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), train_losses, label="Training Loss", marker='o')
plt.plot(range(1, epochs + 1), val_losses, label="Validation Loss", marker='x')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), val_accuracies, label="Validation Accuracy", marker='s', color='g')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs + 1), train_losses, label="Training Loss", marker='o')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import precision_recall_fscore_support

test_loss = 0.0
correct = 0.0
preds = []
labels_ = []

with torch.no_grad():
    model.eval()
    for i, (inputs, labels) in enumerate(dataloader_test):
        inputs = inputs.squeeze(1).to(device)
        inputs = inputs.repeat(1, 3, 1, 1) # For models that need 3 channels
        labels = labels.to(device).type(torch.float)

        outputs = model(inputs)
        preds.extend(outputs.round().cpu().numpy())
        labels_.extend(labels.round().cpu().numpy())

        loss = criterion(outputs, labels)
        test_loss += loss.item() * inputs.size(0)
        correct += (outputs.round() == labels).float().sum().item()

acc = correct / len(dataloader_test.dataset)
avg_loss = test_loss / len(dataloader_test.dataset)
precision, recall, fscore, _ = precision_recall_fscore_support(labels_, preds, average="weighted", zero_division=np.nan)
print(f"Accuracy: {acc} | Precision: {precision} | Recall: {recall} | F1: {fscore} | Avg Loss: {avg_loss}")
# Out:
# Accuracy: 0.8782051282051282 | Precision: 0.8843300950464723 | Recall: 0.8782051282051282 | F1: 0.8802609191081001 | Avg Loss: 0.37069497200158924

# %%
conf_matrix = confusion_matrix(labels_, preds)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Negativo', 'Positivo'], yticklabels=['Negativo', 'Positivo'])
plt.xlabel('Predito')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()
